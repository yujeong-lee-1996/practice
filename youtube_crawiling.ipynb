# %%
# !pip install google-api-python-client
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting google-api-python-client
#   Downloading google_api_python_client-2.169.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting httplib2<1.0.0,>=0.19.0 (from google-api-python-client)
#   Downloading httplib2-0.22.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0 (from google-api-python-client)
#   Downloading google_auth-2.39.0-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting google-auth-httplib2<1.0.0,>=0.2.0 (from google-api-python-client)
#   Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5 (from google-api-python-client)
#   Downloading google_api_core-2.24.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting uritemplate<5,>=3.0.1 (from google-api-python-client)
#   Downloading uritemplate-4.1.1-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting googleapis-common-protos<2.0.0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Downloading googleapis_common_protos-1.70.0-py3-none-any.whl.metadata (9.3 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Downloading protobuf-6.30.2-cp310-abi3-win_amd64.whl.metadata (593 bytes)
# Collecting proto-plus<2.0.0,>=1.22.3 (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client)
#   Downloading proto_plus-1.26.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in c:\programdata\miniconda3\envs\python-env-311\lib\site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.32.3)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client)
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client)
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client)
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in c:\programdata\miniconda3\envs\python-env-311\lib\site-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client) (3.2.1)
# Collecting pyasn1<0.7.0,>=0.6.1 (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0,>=1.32.0->google-api-python-client)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\miniconda3\envs\python-env-311\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\miniconda3\envs\python-env-311\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\miniconda3\envs\python-env-311\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\miniconda3\envs\python-env-311\lib\site-packages (from requests<3.0.0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0,>=1.31.5->google-api-python-client) (2025.1.31)
# Downloading google_api_python_client-2.169.0-py3-none-any.whl (13.3 MB)
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ------- -------------------------------- 2.4/13.3 MB 11.2 MB/s eta 0:00:01
#    -------------- ------------------------- 4.7/13.3 MB 11.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.3/13.3 MB 11.6 MB/s eta 0:00:01
#    ----------------------------- ---------- 9.7/13.3 MB 11.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.8/13.3 MB 11.0 MB/s eta 0:00:01
#    ---------------------------------------- 13.3/13.3 MB 10.3 MB/s eta 0:00:00
# Downloading google_api_core-2.24.2-py3-none-any.whl (160 kB)
# Downloading google_auth-2.39.0-py2.py3-none-any.whl (212 kB)
# Downloading google_auth_httplib2-0.2.0-py2.py3-none-any.whl (9.3 kB)
# Downloading httplib2-0.22.0-py3-none-any.whl (96 kB)
# Downloading uritemplate-4.1.1-py2.py3-none-any.whl (10 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading googleapis_common_protos-1.70.0-py3-none-any.whl (294 kB)
# Downloading proto_plus-1.26.1-py3-none-any.whl (50 kB)
# Downloading protobuf-6.30.2-cp310-abi3-win_amd64.whl (431 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Installing collected packages: uritemplate, pyasn1, protobuf, httplib2, cachetools, rsa, pyasn1-modules, proto-plus, googleapis-common-protos, google-auth, google-auth-httplib2, google-api-core, google-api-python-client
# Successfully installed cachetools-5.5.2 google-api-core-2.24.2 google-api-python-client-2.169.0 google-auth-2.39.0 google-auth-httplib2-0.2.0 googleapis-common-protos-1.70.0 httplib2-0.22.0 proto-plus-1.26.1 protobuf-6.30.2 pyasn1-0.6.1 pyasn1-modules-0.4.2 rsa-4.9.1 uritemplate-4.1.1
#   WARNING: The scripts pyrsa-decrypt.exe, pyrsa-encrypt.exe, pyrsa-keygen.exe, pyrsa-priv2pub.exe, pyrsa-sign.exe and pyrsa-verify.exe are installed in 'C:\Users\tq100\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# !pip install tqdm
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting tqdm
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: colorama in c:\programdata\miniconda3\envs\python-env-311\lib\site-packages (from tqdm) (0.4.6)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: tqdm
# Successfully installed tqdm-4.67.1
#   WARNING: The script tqdm.exe is installed in 'C:\Users\tq100\AppData\Roaming\Python\Python311\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import googleapiclient.discovery
from googleapiclient.errors import HttpError

import pandas as pd
import time
import tqdm

# %%
# YouTube API key
API_KEY = "AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE" # YOUR-API-KEY
youtube = googleapiclient.discovery.build("youtube", "v3", developerKey=API_KEY)

# %%
# Get video ids for query. Youtube API allows only up to 50 videos
# 검색어(query))로 유튜브에서 최대 max_results만큼의 동영상 ID를 가져옴.

def get_video_ids(query, max_results=100):
    video_ids = []
    results_per_page = 50  # YouTube API maxResults 
    pages = (max_results + results_per_page - 1) // results_per_page  # calculate #pages
    next_page_token = None
    
    for _ in range(pages): # call api as many times as #pages
        try:
            request = youtube.search().list(
                q=query,
                part="snippet",
                maxResults=results_per_page,
                type="video",
                pageToken=next_page_token
            )
            response = request.execute()      

            # Only check if 'id' key exists and 'videoId' is accessible
            for item in response['items']:
                if isinstance(item, dict) and 'id' in item and 'videoId' in item['id']:
                    video_ids.append(item['id']['videoId'])

            next_page_token = response.get('nextPageToken')
            if not next_page_token:
                break

        except HttpError as e:
            error_reason = e.resp.get('reason')
            if error_reason == 'quotaExceeded':
                print("Quota exceeded. Saving collected data...")
                save_data_to_csv(video_comments)
                exit()
            else:
                print(f"An error occurred: {e}")
                
    return video_ids[:max_results]

# %%
# Get comments for 1 video. Youtube API allows only up to 100 comments per video
# 해당 video_id의 최상위 댓글들을 가져오기.


def get_top_korean_comments(video_id, max_results=100):
    comments = []
    try:
        request = youtube.commentThreads().list(
            part="snippet",
            videoId=video_id,
            maxResults=max_results,
            textFormat="plainText"
        )
        response = request.execute()

        for item in response['items']:
            comment = item['snippet']['topLevelComment']['snippet']['textDisplay']
            comments.append(comment)  
                
    except HttpError as e:
        error_reason = e.resp.get('reason')
        if error_reason == 'commentsDisabled':
            print(f"Comments are disabled for video {video_id}. Skipping.")
        elif error_reason == 'quotaExceeded':
            print("Quota exceeded. Saving collected data...")
            save_data_to_csv(video_comments)
            exit()
        else:
            print(f"An error occurred: {e}")
    
    return comments

# %%
# Make data to dataframe
# video_comments looks like: {"4DUYBXdUYzA": ["와 재밌다", "재미없다", ]}
# video_id: [댓글 리스트] 형태의 데이터를 DataFrame으로 만들어 CSV 파일로 저장.

def save_data_to_csv(video_comments):    
    
    data = {"Video_ID": [], "Comment": []}
    
    for video_id, comments in video_comments.items():
        for comment in comments:
            data["Video_ID"].append(video_id)
            data["Comment"].append(comment)

    df = pd.DataFrame(data)
    
    # Export to CSV 
    df.to_csv("data-files/youtube_comments.csv", index=False)

# %%
participants = ["랩/힙합","빅나티", "애쉬아일랜드", "릴러말즈", "한요한", "정진우", "기리보이", "자이언티", "쏠",
 "로꼬", "죠지", "앰비션뮤직", "VMC","딥플로우", "던밀스", "넉살", "CAMO", "TOIL"]

# %%
video_comments = {}
# Ex: {"4DUYBXdUYzA": ["와 재밌다", "재미없다", ]}

start = time.time()
query_baisic = "랩/힙합"

for participant in tqdm.tqdm(participants):
    query = query_baisic + " " + participant 

    try:
        video_ids = get_video_ids(query, max_results=50) 

        for video_id in video_ids:
            comments = get_top_korean_comments(video_id)
            video_comments[video_id] = comments
    except HttpError as e:
        if e.resp.get('reason') == 'quotaExceeded':
            print("Quota exceeded. Saving collected data...")
            save_data_to_csv(video_comments)
            exit()

    end = time.time()    
    print(f"{end - start}s for query: {query}")    

save_data_to_csv(video_comments)
# Out:
#   6%|▌         | 1/18 [00:14<04:09, 14.67s/it]
# 14.735228061676025s for query: 랩/힙합 랩/힙합
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=-cYLGLT_2N4&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
#  11%|█         | 2/18 [00:26<03:29, 13.06s/it]
# 26.673197031021118s for query: 랩/힙합 빅나티
#  17%|█▋        | 3/18 [00:39<03:11, 12.80s/it]
# 39.15550780296326s for query: 랩/힙합 애쉬아일랜드
#  22%|██▏       | 4/18 [00:51<02:57, 12.70s/it]
# 51.70840644836426s for query: 랩/힙합 릴러말즈
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=JXmypr49UZk&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
#  28%|██▊       | 5/18 [01:03<02:40, 12.36s/it]
# 63.44963073730469s for query: 랩/힙합 한요한
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=K31xK2A3luw&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=5PUPEcu2o44&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=CA1Y0Yj9FXA&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=Gz4iK0E1ovw&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=0iJva2bmxX4&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=a4eho-lprOk&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=EbmuKljKe9I&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=J5QiaqvVuzI&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=EzOUGhMOYy4&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=0OBDSEOA5rg&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=WnSTUNdRdLU&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=QJbFmypS6f4&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=dv15eWje3dA&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=B6zBQkqjx3M&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=_R3GSvvkT54&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=i8obFo6CnGI&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=0x-rxzxDKqc&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=JAtUTrE2SOo&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=wHzn8HC5D74&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=Msae1v2Qy-Y&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=SpwMIEltD8M&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
#  33%|███▎      | 6/18 [01:11<02:11, 10.97s/it]
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=MO2ooi28O44&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=YIMlHQBhNlg&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# 71.73036289215088s for query: 랩/힙합 정진우
#  39%|███▉      | 7/18 [01:23<02:05, 11.37s/it]
# 83.93239521980286s for query: 랩/힙합 기리보이
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=QzLFcfCEm-I&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
#  44%|████▍     | 8/18 [01:36<01:58, 11.88s/it]
# 96.89785933494568s for query: 랩/힙합 자이언티
#  50%|█████     | 9/18 [01:47<01:44, 11.56s/it]
# 107.75288653373718s for query: 랩/힙합 쏠
#  56%|█████▌    | 10/18 [01:58<01:31, 11.41s/it]
# 118.83516597747803s for query: 랩/힙합 로꼬
#  61%|██████    | 11/18 [02:09<01:18, 11.25s/it]
# 129.7018027305603s for query: 랩/힙합 죠지
#  67%|██████▋   | 12/18 [02:22<01:09, 11.59s/it]
# 142.09296655654907s for query: 랩/힙합 앰비션뮤직
#  72%|███████▏  | 13/18 [02:33<00:57, 11.58s/it]
# 153.6302888393402s for query: 랩/힙합 VMC
#  78%|███████▊  | 14/18 [02:43<00:44, 11.15s/it]
# 163.7895634174347s for query: 랩/힙합 딥플로우
#  83%|████████▎ | 15/18 [02:55<00:34, 11.46s/it]
# 175.96963739395142s for query: 랩/힙합 던밀스
#  89%|████████▉ | 16/18 [03:08<00:23, 11.69s/it]
# 188.17973852157593s for query: 랩/힙합 넉살
#  94%|█████████▍| 17/18 [03:20<00:11, 11.78s/it]
# 200.19695210456848s for query: 랩/힙합 CAMO
# An error occurred: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId=wZgsxnYqHps&maxResults=100&textFormat=plainText&key=AIzaSyAL7DBUEkBaAYiiya7iXYFNrxMiQjJwBBE&alt=json returned "The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.". Details: "[{'message': 'The video identified by the <code><a href="/youtube/v3/docs/commentThreads/list#videoId">videoId</a></code> parameter has disabled comments.', 'domain': 'youtube.commentThread', 'reason': 'commentsDisabled', 'location': 'videoId', 'locationType': 'parameter'}]">
# 100%|██████████| 18/18 [03:30<00:00, 11.72s/it]
# 210.97791957855225s for query: 랩/힙합 TOIL

# %%
comments = pd.read_csv("data-files/youtube_comments.csv")

# %%
comments.head()
# Out:
#       Video_ID                                            Comment
# 0  VtJ_2SbYoIM  0:00:01 Paul Blanco - Summer\r\n0:03:17 김승민 - ...
# 1  VtJ_2SbYoIM                                   외국에서 듣는 노래 너무 좋아
# 2  VtJ_2SbYoIM                                        paul Blanco
# 3  VtJ_2SbYoIM                                             밴쿠버ㄹㅈㄷ
# 4  VtJ_2SbYoIM                                                  ㅡ

# %%
pip install konlpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting konlpy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl.metadata (1.9 kB)
# Collecting JPype1>=0.7.0 (from konlpy)
#   Downloading jpype1-1.5.2-cp311-cp311-win_amd64.whl.metadata (5.0 kB)
# Collecting lxml>=4.1.0 (from konlpy)
#   Downloading lxml-5.4.0-cp311-cp311-win_amd64.whl.metadata (3.6 kB)
# Requirement already satisfied: numpy>=1.6 in c:\programdata\miniconda3\envs\python-env-311\lib\site-packages (from konlpy) (2.2.3)
# Requirement already satisfied: packaging in c:\programdata\miniconda3\envs\python-env-311\lib\site-packages (from JPype1>=0.7.0->konlpy) (24.2)
# Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#    ---------------------------------------- 0.0/19.4 MB ? eta -:--:--
#    ---- ----------------------------------- 2.1/19.4 MB 10.7 MB/s eta 0:00:02
#    --------- ------------------------------ 4.5/19.4 MB 11.2 MB/s eta 0:00:02
#    ------------ --------------------------- 6.0/19.4 MB 10.0 MB/s eta 0:00:02
#    ----------------- ---------------------- 8.4/19.4 MB 10.0 MB/s eta 0:00:02
#    --------------------- ------------------ 10.5/19.4 MB 10.4 MB/s eta 0:00:01
#    ------------------------- -------------- 12.6/19.4 MB 10.2 MB/s eta 0:00:01
#    ------------------------------ --------- 14.9/19.4 MB 10.3 MB/s eta 0:00:01
#    --------------------------------- ------ 16.3/19.4 MB 9.8 MB/s eta 0:00:01
#    ------------------------------------- -- 18.1/19.4 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------  19.4/19.4 MB 9.6 MB/s eta 0:00:01
#    ---------------------------------------- 19.4/19.4 MB 9.2 MB/s eta 0:00:00
# Downloading jpype1-1.5.2-cp311-cp311-win_amd64.whl (356 kB)
# Downloading lxml-5.4.0-cp311-cp311-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ------------------------ --------------- 2.4/3.8 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 9.1 MB/s eta 0:00:00
# Installing collected packages: lxml, JPype1, konlpy
# Successfully installed JPype1-1.5.2 konlpy-0.6.0 lxml-5.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# from konlpy.tag import Okt
# okt = Okt()

# %%
# # NULL check
# print(comments.isnull().values.any()) # => True

# comments = comments.dropna(how = 'any') # drop rows with null values

# print(comments.isnull().values.any()) # => False
# Out:
# True
# False

# %%
# stopwords = ['의','가','이','은','들','는','좀','잘','걍','과','도','를','으로','자','에','와','한','하다']

# tokenized_data = []

# # merged_df['text'] => comments['Comment']
# for sentence in tqdm.tqdm(comments['Comment']): 
#     sentence = str(sentence).strip()
    
#     if not sentence:  # 빈 문자열이면 건너뛰기
#         continue
        
#     tokenized_sentence = okt.morphs(sentence, stem=True) # 토큰화
#     stopwords_removed_sentence = [word for word in tokenized_sentence 
#                                   if not word in stopwords # 조건1
#                                      and len(word) >= 2 # 조건2   
#                                      and word.isalpha()]  # 한글이나 영어 
    
#     if stopwords_removed_sentence:  # 빈 리스트가 아니라면 추가
#         tokenized_data.append(stopwords_removed_sentence)
# Out:
#   0%|          | 0/35848 [00:00<?, ?it/s]
# 100%|██████████| 35848/35848 [02:22<00:00, 251.79it/s]

# %%
# len(tokenized_data)
# Out:
# 33402

# %%
# !pip install gensim

# %%
# tokenized_data
# Out:
# [['Paul',
#   'Blanco',
#   'Summer',
#   '김승민',
#   '기쁨',
#   '벤틀리',
#   '끄다',
#   '거야',
#   '애쉬',
#   '아일랜드',
#   '악몽',
#   'TOIL',
#   '검정색',
#   '하트',
#   'Skinny',
#   'Brown',
#   'TOIL',
#   'Don',
#   'flex',
#   'on',
#   'me',
#   '서동현',
#   'vancouver',
#   '재다',
#   '안다'],
#  ['외국', '에서', '듣다', '노래', '너무', '좋다'],
#  ['paul', 'Blanco'],
#  ['밴쿠버', 'ㄹㅈㄷ'],
#  ['운전', '매번', '호강'],
#  ['플레이', '노동요', '최고'],
#  ['어떻다', '좋아하다', '노래', '담다', '두다'],
#  ['넴새', '나다'],
#  ['플리', '훔치다', '보다', '똑같다'],
#  ['오다', '플리', '진짜', '최애'],
#  ['쌍용', '고등학교', '이현준', 'ㅣㅂ'],
#  ['안녕하다',
#   '인의',
#   '초등학교',
#   '채린',
#   '이다',
#   '달기',
#   '숙제',
#   '위해',
#   '댓글',
#   '있다',
#   '좋다',
#   '노래',
#   '들려주다',
#   '감사하다'],
#  ['우연히',
#   '되다',
#   '채널',
#   '인데',
#   '음악',
#   '담기다',
#   '감정',
#   '노력',
#   '너무',
#   '오다',
#   '닿다',
#   '감동',
#   '받다',
#   '만들다',
#   '노래',
#   '채널',
#   '운영',
#   '인데',
#   '시간',
#   '되다',
#   '들다',
#   '함께',
#   '음악',
#   '이야기',
#   '나누다',
#   '계속',
#   '응원'],
#  ['이건', '진짜', '취향', '저격', '주인', '센스', '미치다', '감성', '터지다', '힙합', '최고'],
#  ['그때',
#   '그만하다',
#   '끄다',
#   '물다',
#   '잡다',
#   '진짜',
#   '후회되다',
#   '상황',
#   '생각',
#   '하고',
#   '매번',
#   '상황',
#   '넘다',
#   '나르다',
#   '해주다',
#   '이글',
#   '읽다',
#   '좋다'],
#  ['너무', '감미롭다', '멜로디', '모두', '건강하다', '행복하다'],
#  ['오다', '기쁨', '벤틀리', '끄다', '알다', '사람', '진짜', '없다', '넣다', '감사하다'],
#  ['주인', '취향', '미치다', '노래', '하나', '하나', '분위기', '끝판', '이네'],
#  ['좋아하다',
#   '노래',
#   '밖에',
#   '없다',
#   '하나',
#   '하나',
#   '찾기',
#   '귀찮다',
#   '이렇게',
#   '노래',
#   '아두',
#   '니까',
#   '너무',
#   '좋다',
#   '오늘',
#   '갈다',
#   '들다',
#   '가다',
#   '감사하다'],
#  ['아동', '범죄자', '의심', '신고', '이웃', '야하다', '갑작스럽다', '주변', '돌보다'],
#  ['영상', '사진', '붙다', '니케', '포스터', '띄다'],
#  ['도덕',
#   '시간',
#   '달기',
#   '이다',
#   '좋다',
#   '노래',
#   '많이',
#   '담다',
#   '플레이',
#   '리스트',
#   '제공',
#   '해주다',
#   '감사하다'],
#  ['amazing', 'playlist', 'like', 'it'],
#  ['안녕하다',
#   '중학교',
#   '학년',
#   '도덕',
#   '시간',
#   '과제',
#   '선플',
#   '좋다',
#   '많이',
#   '받다',
#   '있다',
#   '댓글',
#   '보고',
#   '있다',
#   '모두',
#   '모두',
#   '행복하다',
#   '건강하다',
#   '남다',
#   '무탈',
#   '보내다',
#   '바라다'],
#  ['안녕하다',
#   '수업',
#   '시간',
#   '활동',
#   '달기',
#   '운동',
#   '있다',
#   '일리',
#   'ely',
#   '께서',
#   '좋다',
#   '노래',
#   '모으다',
#   '열심히',
#   '만들다',
#   '감사하다',
#   '으로도',
#   '좋다',
#   '노래',
#   '모음',
#   '영상',
#   '부탁드리다',
#   '매일',
#   '하루',
#   '행복하다',
#   '화이팅'],
#  ['노래',
#   '너무',
#   '듣기',
#   '좋다',
#   '요즘',
#   '듣다',
#   '싶다',
#   '노래',
#   '없다',
#   '힙합',
#   '노래',
#   '듣다',
#   '있다',
#   '너무',
#   '좋다'],
#  ['안녕하다',
#   '동지',
#   '여자',
#   '중학교',
#   '학년',
#   '학생',
#   '이다',
#   '도덕',
#   '시간',
#   '달기',
#   '활동',
#   '이다',
#   '요즘',
#   '아침',
#   '학교',
#   '갈다',
#   '준비',
#   '마다',
#   '플리',
#   '듣다',
#   '축축',
#   '치다',
#   '학교',
#   '가다',
#   '아침',
#   '그나마',
#   '기운',
#   '내미다',
#   '준비',
#   '있다',
#   '가다',
#   '으로도',
#   '좋다',
#   '플리',
#   '많이',
#   '내쥬세'],
#  ['요즘', '뜨다', '사랑', '감성', '힙합', '추천', '해주다', '안되다', '너무', '이미', '유명하다', '노래'],
#  ['두번째', '미치다', '진쨔', '취향', '올려주다', '그랜절'],
#  ['나이키',
#   '신고',
#   '어어',
#   '어어',
#   '어어',
#   '어어',
#   '어어',
#   '어어',
#   '어어',
#   '어어',
#   '어어',
#   '어어',
#   '어어',
#   '어어',
#   '어어',
#   '어어',
#   '어어',
#   '어어',
#   '어어',
#   '어어',
#   '어어',
#   '어어',
#   '어어',
#   '어어'],
#  ['사랑',
#   '이라는',
#   '그저',
#   '말로',
#   '아니다',
#   '때로는',
#   '작다',
#   '행동',
#   '이나',
#   '눈빛',
#   '미소',
#   '하나로',
#   '전해질',
#   '있다',
#   '그래서',
#   '만약',
#   '보고',
#   '있다',
#   '당신',
#   '사랑',
#   '좋다',
#   '하루',
#   '되다'],
#  ['ㅋㅋㅋ'],
#  ['부터', '완벽'],
#  ['don', 'understand', 'lyrics', 'but', 'these', 'songs', 'are', 'vibe'],
#  ['따다'],
#  ['청춘', '자체'],
#  ['요즘', '지난', '너무', '그리다', '다시', '시절', '돌아가다', '더더', '자다', '보고', '싶다', 'ㅠㅠ'],
#  ['이름', '에요'],
#  ['부터',
#   '썸머',
#   '감다',
#   '진짜',
#   '느좋',
#   '플리',
#   '감성',
#   '힙합',
#   '센스',
#   '있다',
#   '모으다',
#   '두다',
#   '최고',
#   '에여'],
#  ['느좋'],
#  ['오다', '노래', '개조', '들다', '오늘', '홧팅'],
#  ['진짜', '들다', '보다', '플리', '좋다'],
#  ['맛있다', '노래', '모으다', 'ㅋㅋ', '개추', '박다', '가다'],
#  ['광고', '시벌'],
#  ['감성', '힙합', '플리', '밴쿠버', '무조건', '이네', '하여튼', '띵곡', '이야'],
#  ['사진',
#   '혹시',
#   '핀더레스트',
#   '에서',
#   '가져오다',
#   '건가',
#   '구매',
#   '하고',
#   '유투브',
#   '올리다',
#   '되다',
#   '혹시',
#   '저작권',
#   '문제',
#   '있다',
#   '싶다'],
#  ['좋다', '노래', '듣다', '여윽시', '똑똑하다', '사람', '시월', '모바일', '알뜰폰', '쓴다'],
#  ['유튜브', '힙합', '치다', '좋다', '노래', '목록', '진짜', '신기하'],
#  ['기분',
#   '좋다',
#   '나쁘다',
#   '않다',
#   '뭔가',
#   '조금',
#   '이라도',
#   '상처',
#   '받다',
#   '바로',
#   '무너지다',
#   '같다',
#   '느낌',
#   '이라',
#   '자다',
#   '노래',
#   '자다'],
#  ['혹시', '배경화면', '있다', '너무', '이쁘다', 'ㅜㅜ'],
#  ['번째', '이름', '뭔가'],
#  ['힙합', '너무', '좋다', 'ㅠㅠㅠ'],
#  ['들다', '까지', '남기다', '겁니다'],
#  ['여기', '댓글', '이래', '요오', 'ㅜㅜ', '따다', '좋다', '노래', '듣다'],
#  ['부터', '미치다'],
#  ['노래', '좋다'],
#  ['노래', '너무', '좋다'],
#  ['아니다',
#   '일리',
#   '플리',
#   '항상',
#   '너무',
#   '취향',
#   '이라',
#   '듣다',
#   '있다',
#   '최애',
#   '까지',
#   '완벽하다',
#   '똑같다'],
#  ['빅스', '에게', '힙합', '음악', '틀다', '달라', '하니', '영상', '틀어주다'],
#  ['감사하다'],
#  ['작업', '들다', '능률', '올라가다', '감사하다', 'ㅎㅎㅎㅎ'],
#  ['생각', '보다', '너무', '메이저', '이라', '있다'],
#  ['잠깐', '쉬다', '적다', '보다', '어린시절', '보다', '그대', '무엇', '이다'],
#  ['매일', '아침', '뜨다', '듣다', '싶다', '노래', '이다'],
#  ['자다', '들다'],
#  ['좋다'],
#  ['화면',
#   '주인공',
#   '처럼',
#   '자유로',
#   '보이다',
#   '십대',
#   '보내다',
#   '음악',
#   '들다',
#   '십대',
#   '십대',
#   '여러분',
#   '자유',
#   '만끽',
#   '눈치',
#   '보지',
#   '말고',
#   '싶다',
#   '미치다',
#   '집중',
#   '계절',
#   '주다',
#   '변화',
#   '느끼다',
#   '지내다',
#   '바라다'],
#  ['처음', '부터', '썸머', 'ㅜㅜ', '알다', 'ㅜㅜ'],
#  ['평소', '유튜브', '듣다', '플레이', '리스트', '갖다', '오다', 'ㅎㄷㄷ'],
#  ['ㅁㅊ', '선생님', '사랑', '맨날', '노래', '들다', '힐링', '햡니댜'],
#  ['ㅇㄴ',
#   '썸머',
#   '듣다',
#   '혼자',
#   '신나다',
#   '프리스타일',
#   '춤추다',
#   '있다',
#   '침대',
#   '박다',
#   'ㅋㅋㅋㅋㅌㅋ',
#   '진짜',
#   '오다',
#   'ㅠㅠㅠㅠㅠ'],
#  ['노래', '맛있다'],
#  ['조음'],
#  ['아니다', '사랑', '진짜', '타임', '라인', '보다', '구독', '누르다', '좋아하다', '있다'],
#  ['오다', 'ㅏㅏ', '좋아하다', '밖에', '없다'],
#  ['노래', '부드럽다', '리듬', '긴장', '스트레스', '해소', '도움', '되다'],
#  ['안치', '좋다', '있다'],
#  ['언니', '솔직하다', '재생', '목록', '해킹'],
#  ['너무',
#   '기다',
#   '질린다',
#   '댓글',
#   '보고',
#   '바로',
#   '피드백',
#   '가요',
#   '기다',
#   '좋다',
#   '가끔',
#   '오다',
#   '세요'],
#  ['읽다',
#   '있다',
#   '사람',
#   '누구',
#   '인지',
#   '모르다',
#   '만약',
#   '당신',
#   '라면',
#   '당신',
#   '인생',
#   '에서',
#   '좋다',
#   '모든',
#   '받다',
#   '자격',
#   '있다',
#   '알다',
#   '좋다',
#   '어디',
#   '있다',
#   '평화',
#   '행복',
#   '사랑',
#   '바라다'],
#  ['사람', '보다'],
#  ['썸머', '부터', '시작', '이라니', '둑흔둑흔', '이다'],
#  ['크으', '애용'],
#  ['미치다', '파트'],
#  ['오다', '이랑', '두번째', '노래', '진짜', '너무', '좋다'],
#  ['음성', '건달', '메기', '김준수', '의대'],
#  ['미치다', '음감', '천재'],
#  ['가수', '이름'],
#  ['너무',
#   '좋다',
#   '실제',
#   '있다',
#   '인가요',
#   'AI',
#   '인가요',
#   '댓글',
#   '자곡',
#   '이라고',
#   '내용',
#   '있다',
#   '궁금하다',
#   '질문',
#   '드리다'],
#  ['보이'],
#  ['심장마비', '심장', '충격', '가다', '들다'],
#  ['덕분',
#   '종종',
#   '자다',
#   '듣다',
#   '특히',
#   '깁다',
#   '필요하다',
#   '아쉽다',
#   '노래',
#   '제목',
#   '들이다',
#   '익숙하다',
#   '멜로디',
#   '에도',
#   '제목',
#   '떠오르다',
#   '않다',
#   '네이버',
#   '다음',
#   '에서',
#   '음악',
#   '검색',
#   '을해',
#   '먹통',
#   '그렇다'],
#  ['진짜', '빠지다'],
#  ['스트레스', '풀리다', '작곡', '이름', '이라도', '싶다', 'ㅠㅠ'],
#  ['직접', '부르다', '에요'],
#  ['벨소리', '능지'],
#  ['우와', '너무', '감사하다'],
#  ['스타일'],
#  ['굳다'],
#  ['스트레스', '날아가다', '넘다'],
#  ['대박', '작곡', '이여', '구독'],
#  ['감사하다'],
#  ['노래', '최고', '자전거', '타다', '들다', '거리', '늘어나다'],
#  ['안녕하다', '번째', '음원', '댄스', '안무', '써다', '보고', '싶다', '가능하다'],
#  ['노래', '취향', '저격', '이다', '구독', '좋다', '누르다', '듣다', '있다'],
#  ['놀이', '공원', '보다', '짜릿짜릿', '보다'],
#  ['번째',
#   '음악',
#   '듣다',
#   '깜짝',
#   '놀라다',
#   '구독',
#   '하트',
#   '바로',
#   '누르다',
#   '검색',
#   '안되다',
#   '만들다',
#   '능력',
#   '자심',
#   '번째',
#   '음악',
#   '비트',
#   '하나',
#   '만들다',
#   '소원',
#   '없겠슴'],
#  ['메탈', '최고', '밉다'],
#  ['이틀', '만에', '번째', '듣다', '최고'],
#  ['노래', '제목', '리스트', '올리다', '주다'],
#  ['지루하다', '저녁', '힐링', '제대로', '감사하다'],
#  ['오다', '멋지다', '둥둥'],
#  ['광고', '없이', '들다', '어케'],
#  ['노래', '좋다', '지루하다', '퇴근길', '씐나', '운전', '들다', '감삼돠'],
#  ['고맙다'],
#  ['늦다', '출첵'],
#  ['오다', '진짜', '쩐다', '까지', '완전', '스퇄', 'ㅣㄹ', 'ㅏㄹ'],
#  ['개쩌'],
#  ['대단하다', '자다', '들다'],
#  ['노래', '만들다', '가사', '라도', '알다', 'ㅠㅠ'],
#  ['노래', '제목', '없다'],
#  ['안녕하다'],
#  ['좋다', '노래', '자다', '듣다', '가다', '그루브', '제작', '하고', '있다', '놀다', '세용'],
#  ['빠지다', '대인', '대물', '접수', '해주다', 'ㅡㅡ'],
#  ['니미', '노래', '섹타', '완전', '취향'],
#  ['좋다', '직접', '만들다', '노래', '라니', '놀라다', '좋다', '노래', '감사하다'],
#  ['요즘', '꽂히다', '매일', '듣다', '흥이나다', '힙합', '대회', '나가다', '최우수상', 'ㅋㅋ'],
#  ['번은', '워테', '파크', '에서', '들리다', '같다'],
#  ['고속도로', '졸리다', '깨다'],
#  ['구독', '박아', '노래', '제목', '알다'],
#  ['노래', '제목', '적다'],
#  ['제작자',
#   '노래',
#   '제목',
#   '있다',
#   '정중하다',
#   '여쭈다',
#   '보고',
#   '부탁드리다',
#   '립니',
#   '노래',
#   '들다',
#   '예전',
#   '생각',
#   '많이',
#   '나서다',
#   '그렇다'],
#  ['미치다', '제목'],
#  ['노래', '듣다', '급발진', '부웅'],
#  ['출근', '들다', '안되다'],
#  ['노래', '재목'],
#  ['노래', '제목'],
#  ['와우', 'ㅡㅡㅡㅡㅡㅡㅡ'],
#  ['으로가', '에요'],
#  ['뮤직', '완벽하다'],
#  ['미쳣다', '구독', '좋다'],
#  ['노래', '제목', '가수', '적히다', '아쉽다'],
#  ['오다', '처음'],
#  ['바로', '구독', '가다'],
#  ['운동', '들다', '덤벨', '사람', '아드레날린', 'ㅋㅋㅋㅋ'],
#  ['광고', '때메', '좋다'],
#  ['스타일', '이네', '경쾌하다', '비트', '가볍다', '딕션', '이다'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['와우', '미군', '부대', '근처', '클럽', '너무', '좋다', '흔들다', '흔들다'],
#  ['Pilumeue'],
#  ['때리다', '박다', '취향', '이네', '정말', '감사하다'],
#  ['플리', '알다'],
#  ['제목'],
#  ['듣다', '바로', '구독'],
#  ['오다', '뭔가', '넘다', '좋다'],
#  ['Thank', 'you', 'verymuch'],
#  ['대박', '이다'],
#  ['잘듵어', 'ㅎㅎ', '배우다'],
#  ['멋지다', '뿜뿜', '음악', '너무', '느낌', '있다', '좋다', '자다', '듣다', '가다'],
#  ['구독', '박다', '음악', '쌈뽕', '허니', '맛집', '이네'],
#  ['ㅋㅋ', '있다', '큰일', '날뻔', 'ㅋㅋ'],
#  ['퇴근', '듣다', '악세다', '밟다', '책임지다'],
#  ['일단', '구독', '박다'],
#  ['여기', '맛집', '이네', '단골', '가즈'],
#  ['광고',
#   'TRACKLIST',
#   '사이먼',
#   '도미',
#   'Simon',
#   'Dominic',
#   '물음표',
#   '프라이머리',
#   'Aqua',
#   'man',
#   'Beenzino',
#   '조금',
#   '이따',
#   '샤워',
#   '개리',
#   '갖다',
#   '놀래다',
#   '범키',
#   'All',
#   'wanna',
#   'do',
#   'Jay',
#   'PARK',
#   'Oasis',
#   'CRUSH',
#   'METEOR',
#   '창모',
#   '그대로',
#   '있다',
#   '돼다',
#   'Supreme',
#   'Team',
#   'And',
#   'July',
#   'Heize',
#   'Nike',
#   'shoes',
#   'Beenzino',
#   'Get',
#   'lifted',
#   'PEEJAY',
#   '모르다',
#   'Loco',
#   '죽이다',
#   'Dynamic',
#   'duo',
#   'DEAN',
#   'Real',
#   'Man',
#   'swings',
#   '편하다',
#   'Simon',
#   'Dominic',
#   'Han',
#   'gang',
#   'gang',
#   'The',
#   'Quiett',
#   '호구',
#   'Giriboy',
#   'Peach',
#   'REDDY',
#   'PARTY',
#   'SIK',
#   'Martini',
#   'Blue',
#   'DPR',
#   'LIVE',
#   'Iffy',
#   'SIK',
#   'Ph',
#   '키보',
#   '이즈',
#   '블랙'],
#  ['노이즈', '너무', '들어가다', '어떻다', '되다', '가요'],
#  ['싸이', '멀다', '순간', '뒤집어지다'],
#  ['빨리', '느좋', '국힙', '플레이', '리스트', '주다', '현기증'],
#  ['완전', '좋다'],
#  ['진짜', '댓글', '자다', '안다', '이형', '선곡', 'DJ', '실력', '미치다'],
#  ['마지막', '곡뭐'],
#  ['인데', '요즘', '매일', '공부', '듣다', '구독', '탄도', '기대하다'],
#  ['시스루', '넣다', '넣다'],
#  ['잠들다'],
#  ['국힙', '플레이', '리스트', '만들다'],
#  ['오다', '진짜', '너무', '좋다'],
#  ['생도', '슬쩍', '끼다', '보다'],
#  ['진짜', '감사하다'],
#  ['음악', '도파민', '넘다', '좋다'],
#  ['오다', '진짜', '최고', '감사하다'],
#  ['이렇다', '하나', '해주다', '진짜', '내내', '거만', '들다'],
#  ['공부', '하루', '종일', '플리', '듣다', '플리', '뜨다', '문제', '있다', 'ㄹㅇ'],
#  ['iffy', '나오다', '좋다'],
#  ['이거지'],
#  ['지다',
#   '힙합',
#   '듣다',
#   '들어오다',
#   '너무',
#   '좋다',
#   '구독',
#   '누르다',
#   '가다',
#   '요리',
#   '들다',
#   '너무',
#   '좋다',
#   '살짝',
#   '리듬타다'],
#  ['진짜', '여기', '부터', '소름', '돋다', '좋다'],
#  ['공부', '듣기', '너무', '좋다', '감사하다'],
#  ['사이먼', '도미', '이랑', '물음표', '이어지다', '진짜', '좋다'],
#  ['윤영철', '이냐'],
#  ['아침',
#   '나가다',
#   '준비',
#   '매번',
#   '들다',
#   '진짜',
#   '처음',
#   '부터',
#   '까지',
#   '좋다',
#   '처음',
#   '이에요',
#   '진짜',
#   '들다',
#   '보다',
#   'ㅠㅠ',
#   '너무',
#   '좋다',
#   '타다',
#   '언제',
#   '나오다',
#   '기다리다',
#   '있다'],
#  ['아무',
#   '생각',
#   '없이',
#   '들어오다',
#   '아무',
#   '생각',
#   '없이',
#   '듣다',
#   '노래',
#   '믹스',
#   '처럼',
#   '되어다',
#   '노래',
#   '다양하다',
#   '느낌',
#   '이네',
#   '궁금하다',
#   '영상',
#   '보다',
#   '여러',
#   '처럼',
#   '만들다',
#   '이다',
#   '너무',
#   '좋다',
#   '바로',
#   '좋다',
#   '요랑',
#   '구독',
#   '누르다'],
#  ['약간', '손흥민', '닮다', 'ㅋㅋ'],
#  ['부터',
#   '지리',
#   '바로',
#   '플리',
#   '저장',
#   '좋다',
#   '구독',
#   '갈다',
#   '진짜',
#   '배우',
#   '신분',
#   '이렇다',
#   '플리',
#   '찾다',
#   '없다',
#   '진짜',
#   '오아시스',
#   'ㅜㅜㅜㅜ',
#   '리스트',
#   '보다',
#   '감탄',
#   '나오다',
#   'ㅋㅋㅋㅋ'],
#  ['테오', '도입', '에서', '지코', '짜다', 'ㅋㅋ'],
#  ['지나가다', '생입니다', '진짜', '빼다', '알다', '노래', '좋아하다', '사랑'],
#  ['ㅋㅋㅋㅋㅋ', '진짜', '플리', '제대로', '뽑다'],
#  ['크다', '계정은', '없다', '가요'],
#  ['에픽하이', '노래', '하나', '제발', '넣다', 'ㅜㅜㅜㅜㅜㅜㅜ'],
#  ['진짜', '인생', '플레이', '리스트', '예요', '지우다', '말다', 'ㅠㅠ'],
#  ['미치다', '찾다'],
#  ['진짜', '알고싶다', '그래도', '유튜브', '승승장구', '바라다'],
#  ['오아시스', '테오', '줄라이', '빈지노', '까지', '리스트', '모으다', '안내', '운전', '플리', 'ㅠㅠㅠ'],
#  ['부터'],
#  ['볼링장', '에서', '엄청', '틀어주다', 'ㅋㅋ'],
#  ['썸네일', '앨범커버', '보다', '노래', '래퍼', '이름', '떠오르다', '들어오다', '최고'],
#  ['말년', '호빙요', '항상', '응원'],
#  ['아미', '치다'],
#  ['레디', '수면', 'do', 'better'],
#  ['플리', '미치다'],
#  ['런닝머신', '메이트'],
#  ['리쌍', '노래', '진짜', '좋다'],
#  ['시절', '힙합', '그리다'],
#  ['진짜'],
#  ['love', 'Thank', 'you', 'for', 'the', 'mix'],
#  ['노래', '제목', '뭐에욮'],
#  ['춤추다'],
#  ['추억', '오다', '플리', '잡채', 'ㅠㅠ', '띵곡', '많다', '같다'],
#  ['좋다', '진심'],
#  ['구독'],
#  ['노래', '제목', '함께', '넣다', '좋다', '같다'],
#  ['Dj', '성함', '알다'],
#  ['이르다', '기도', '애매하다', '애매하다', '아니다', '입장', '에서', '세대', '같다', '느낌', '인데'],
#  ['양동근', '형님', '한번', '쓰다', '줄다'],
#  ['부터', '너무', '마음', '들다'],
#  ['진짜', '넘다', '좋다'],
#  ['너무', '자다', '말다', 'ㅠㅠㅠ', '십대', '중반', '인데', '진심', '그냥', '플리'],
#  ['DJ',
#   '좋다',
#   '그때',
#   '기억',
#   '감성',
#   '되다',
#   '달다',
#   '짜다',
#   'DJ',
#   '만들다',
#   '참고',
#   '추다',
#   '퇴근',
#   '시간',
#   '게임',
#   '시간',
#   '들다',
#   '동안',
#   'DJ',
#   '대다',
#   '열쩡'],
#  ['노래', '아시'],
#  ['유일하다',
#   '팔로우',
#   'DJ',
#   '채널',
#   '인데',
#   '이번',
#   '영상',
#   '완전',
#   '취향',
#   '이에요',
#   '탄도',
#   '자다',
#   '부탁드리다'],
#  ['얌전하다', '고양이', '마리', '부뚜막', '올라가다', '리믹스', '버젼', '가능하다', '심다'],
#  ['죠지', '보트', '플리', '넘다', '신나다'],
#  ['좋다'],
#  ['케이', 'fire', '이요'],
#  ['형님', '국힙', '근본', '다듀', 'AEAO', '신청'],
#  ['생인데', '스포티파이', '롭니', '허허'],
#  ['미치다', '플리', '하나', '부터', '까지', '너무', '좋다'],
#  ['약간', '재지팩트', '바이브', '리믹스', '한번', '시원하다', '말다'],
#  ['겁나다', '트렌디', '대생이', '좋아하다', '노래', '돼다'],
#  ['지코', 'boys', 'and', 'girls'],
#  ['댓글', '추천', '해주시', '종합', '탄도', '만들다', '보다'],
#  ['찢다', '었다'],
#  ['𝐏𝐋𝐀𝐘𝐋𝐈𝐒𝐓',
#   '창모',
#   'METEOR',
#   'BE',
#   '리무진',
#   'DRAGON',
#   'POWER',
#   '없이',
#   'Sokodomo',
#   '회전목마',
#   '창모',
#   '마에스트로',
#   'PATEKO',
#   'Rainy',
#   'Day',
#   '지코',
#   '이영지',
#   'Small',
#   'Girl',
#   'Paul',
#   'Blanco',
#   'Summer',
#   '박재범',
#   '좋다',
#   'JOAH',
#   '타치',
#   '호치키스',
#   '빈지노',
#   'Boogie',
#   'on',
#   'on',
#   '송민호',
#   '아낙네',
#   'Dori'],
#  ['플리', '너무', '좋다'],
#  ['오다'],
#  ['너무', '좋다'],
#  ['오다', '이분', '플리', '만들다', '뜨다'],
#  ['거지', 'ㅠㅠㅠㅠㅠㅠ'],
#  ['굿굿굿', '근래', '찾다', '리스트', '쵝오'],
#  ['감사하다'],
#  ['가져오다'],
#  ['모라', '신의한수'],
#  ['둠칫둠칫', '신나요'],
#  ['오다', '선곡', '밉다', '따다'],
#  ['대중픽', '이라', '믿다', '보다', '단골', '가다', '이라', '한번', '들리다', '같다'],
#  ['너무', '대중픽', '이어서'],
#  ['미치다', '플리', '완전', '스타일'],
#  ['아침', '부터', '둠칫둠칫', '오다'],
#  ['오다',
#   '힙합',
#   '먹다',
#   '인데',
#   '어쩜',
#   '이렇게',
#   '대중',
#   '유명하다',
#   '알다',
#   '노래',
#   'ㄷㄷ',
#   '플리',
#   '되다'],
#  ['진짜',
#   '취향',
#   '가득하다',
#   '플리',
#   '이다',
#   '고등',
#   '랩퍼',
#   '밉다',
#   '있다',
#   '힙합',
#   '깔다',
#   '알다',
#   '힙합',
#   '모르다',
#   '사람',
#   '들다',
#   '빠져들다',
#   '같다'],
#  ['여러분',
#   '소중하다',
#   '댓글',
#   '하나',
#   '하나',
#   '읽다',
#   '있다',
#   '정말',
#   '크다',
#   '되다',
#   '있다',
#   '하트',
#   '감사하다',
#   '마음',
#   '표현',
#   '혹시',
#   '듣다',
#   '싶다',
#   '음악',
#   '이나',
#   '추천',
#   '받다',
#   '싶다',
#   '플레이',
#   '리스트',
#   '있다',
#   '언제',
#   '댓글',
#   '남기다'],
#  ['오다', '진짜', '팝송', '힙합', '너무', '좋다', '좋다', '누르다', '가요'],
#  ['집중', '모르다', '스카', '에서', '어깨춤', '자랑', '하고', '있슴다'],
#  ['유일하다', '운곡', '죽이다', '놈임'],
#  ['노래',
#   '가사',
#   '자다',
#   '모르다',
#   '나다',
#   '모르다',
#   '정말',
#   '모르다',
#   '그냥',
#   '쓰다',
#   '진짜',
#   '자다',
#   '모르다',
#   '누군가',
#   '이고',
#   '옥죄기',
#   '싫다',
#   '누군가',
#   '알다',
#   '사람',
#   '나로',
#   '인하다',
#   '죽다',
#   '모습',
#   '이상',
#   '보기',
#   '싫다',
#   '천년',
#   '동안',
#   '지구',
#   '에서',
#   '이미',
#   '많이',
#   '보다',
#   '이미',
#   '모습',
#   '아주',
#   '많이',
#   '보다',
#   '차라리',
#   '대신',
#   '죽다',
#   '속이다',
#   '편하다',
#   '직접',
#   '가다',
#   '싸우다',
#   '다치다',
#   '속이다',
#   '편하다',
#   '그래서',
#   '남자',
#   '태어나다',
#   '모든',
#   '보다',
#   '희생',
#   '너희',
#   '나르다',
#   '위해',
#   '다치다',
#   '죽다',
#   '끔찍하다',
#   '보기',
#   '싫다',
#   '차라리',
#   '죽다',
#   '그렇다',
#   '한번',
#   '인간',
#   '원망하다',
#   '않다',
#   '선택',
#   '이니까',
#   '그건',
#   '언제',
#   '까지나',
#   '선택',
#   '이다',
#   '유진',
#   '죽다',
#   '바라지',
#   '않다',
#   '그래서',
#   '먼저',
#   '죽다',
#   '택했어',
#   '모습',
#   '만큼은',
#   '죽다',
#   '보다',
#   '맞다',
#   '까지',
#   '기적',
#   '이야',
#   '그리고',
#   '으로도',
#   '다치다',
#   '싫다',
#   '아주',
#   '기적',
#   '굳다',
#   '너희',
#   '절대',
#   '보다',
#   '일찍',
#   '죽지',
#   '먼저',
#   '거들다',
#   '그게',
#   '만들다',
#   '놓다',
#   '윤회',
#   '그래서',
#   '아이',
#   '직접',
#   '낳다',
#   '불다',
#   '그래서',
#   '그나마',
#   '매가',
#   '정신',
#   '차리다',
#   '나라',
#   '말다',
#   '그래서',
#   '이름',
#   '악마',
#   '이며',
#   '천사',
#   '되다',
#   '유진',
#   '에게는',
#   '악마',
#   '거들다',
#   '하지만',
#   '혜택',
#   '받다',
#   '인간',
#   '에게는',
#   '천사',
#   '이지',
#   '구원',
#   '해주',
#   '니까',
#   '까지',
#   '기적',
#   '나가다',
#   '그게',
#   '원래',
#   '니까',
#   '그리고',
#   '너희',
#   '죽다',
#   '반드시',
#   '데려가다',
#   '진짜',
#   '노예',
#   '확실하다',
#   '보여주다',
#   '혼자',
#   '서다',
#   '아기',
#   '낳다',
#   '하고',
#   '몸조리',
#   '그리고',
#   '히스테리',
#   '부리다',
#   '받다',
#   '사람',
#   '필요하다',
#   '자다',
#   '태아',
#   '눌려',
#   '쥐다',
#   '저리다',
#   '아프다',
#   '도와주다',
#   '사람',
#   '필요하다',
#   '입덧',
#   '심하다',
#   '에서',
#   '지키다',
#   '사람',
#   '필요하다',
#   '호르몬',
#   '변화',
#   '기분',
#   '갑자기',
#   '심각하다',
#   '우울하다',
#   '눈물',
#   '멈추다',
#   '않다',
#   '에서',
#   '보살피다',
#   '사람',
#   '필요하다',
#   '그리고',
#   '산후',
#   '우울증',
#   '극복',
#   '끄다',
#   '오다',
#   '자살',
#   '같다',
#   '극단',
#   '행동',
#   '돼다',
#   '게다가',
#   '아주',
#   '심하다',
#   '노산',
#   '이라',
#   '도와주다',
#   '남편',
#   '반드시',
#   '있다',
#   '있다',
#   '병원',
#   '데리다',
#   '가끔',
#   '백화점',
#   '갈다',
#   '필요하다',
#   '게다가',
#   '낳다',
#   '아이',
#   '케어',
#   '해주다',
#   '야하다',
#   '가족',
#   '있다',
#   '최소',
#   '동안',
#   '외국',
#   '아주',
#   '훌륭하다',
#   '교육',
#   '받다',
#   '유학',
#   '보내다',
#   '정도',
#   '예산',
#   '여유',
#   '롭고',
#   '충분하다',
#   '당연하다',
#   '전부',
#   '해주다',
#   '아주아주',
#   '기적',
#   '되다',
#   '그게',
#   '생존',
#   '위협',
#   '느끼다',
#   '여자',
#   '방법',
#   '거들다',
#   '사람',
#   '지켜보다',
#   '배우다',
#   '이야',
#   '이상',
#   '깊다',
#   '생각',
#   '그리고',
#   '선택',
#   '에게',
#   '있다',
#   '모두',
#   '그걸',
#   '잊다'],
#  ['도에도', '들다', '사람', '또는', '듣다', '있다', '사람'],
#  ['노래', '가사', '처럼', 'ㄹㅇ', '부족하다', '뭔가', '있다'],
#  ['도에', '듣다', '사람'],
#  ['퍼펙트', '나이', '스샷', '넘버원', '브라보', '살다', '원더풀'],
#  ['명곡', '시간', '상관없다', '가슴', '울림', '주다', '같다'],
#  ['보넥', '듣다', '여기', '까지', '오다'],
#  ['ㅋㅋㅋ'],
#  ['굿굿'],
#  ['정일우', '이민정', '맞다'],
#  ['죽이다', '생각나다'],
#  ['사람', '맛있다', '부르다'],
#  ['아직', '까지', '듣다', '사람'],
#  ['우리', '학교', '수업', 'ㅅㅂ', '학교', '음악', '교과서', '파트', '있다', '노랜', 'ㄹㅇ', '좋다'],
#  ['대로', '돌아가다', 'ㅋㅋㅋ'],
#  ['에서', '불다', '창빈', '지성', '구합', '근데', '나레이션'],
#  ['ㅋㅋ', '좋다'],
#  ['최애'],
#  ['나이', '매니저', '불다', '보로'],
#  ['번잡',
#   '헤어지다',
#   '한번',
#   '잡다',
#   '실패하다',
#   '헤어지다',
#   '누가',
#   '잘못',
#   '한지',
#   '알다',
#   '최선',
#   '이라',
#   '생각',
#   '마지막',
#   '되다',
#   '라는',
#   '생각',
#   '밖에'],
#  ['댓글', '이월', '중순', '이라니'],
#  ['최신', '댓글', '개월', '전이'],
#  ['듣다'],
#  ['듣다'],
#  ['나오다'],
#  ['들다', '늘다', '힘내다'],
#  ['개코', '노래', '부르다'],
#  ['노래', '전남친', '좋아하다', '노래', '라서', '들다', '마다', '생각'],
#  ['전이라니'],
#  ['도에도', '듣다', '사람'],
#  ['좋다'],
#  ['도에', '듣다', '사람'],
#  ['도에', '돌아오다'],
#  ['유죄', '죄책감', '느끼다'],
#  ['에도', '듣다', '사람'],
#  ['에도', '듣다', '사람'],
#  ['듣다', '사람', '있다'],
#  ['에도', '듣다', '사람'],
#  ['존나', '노래'],
#  ['도애도', '듣다', '사람'],
#  ['뛰다',
#   '치다',
#   '차문',
#   '부술',
#   '듯이',
#   '닫다',
#   '머릴쳐박',
#   '숨셔',
#   '핸들',
#   '안다',
#   '제목',
#   '보다',
#   '자동',
#   '나오다'],
#  ['도에도', '듣다', '사람'],
#  ['에도', '듣다', '사람'],
#  ['들다'],
#  ['무조'],
#  ['Here'],
#  ['전여친', '헤어지다', '나서다', '노래', '카톡', '프로필', '노래', '설정', '무슨', '이다'],
#  ['에도', '듣다', '사람'],
#  ['노래'],
#  ['노래', '너무', '좋다'],
#  ['에도', '듣다', '사람'],
#  ['도애도', '듣다', '사람'],
#  ['듣다', '사람'],
#  ['도에듣는사람'],
#  ['Anyone', 'in'],
#  ['이별', '하고', '노래', '들리다'],
#  ['라이브', '들다', '진짜', '좋다'],
#  ['도에', '듣다', '사람'],
#  ['에도', '듣다', '사람'],
#  ['에도', '듣다', '사람'],
#  ['너무', '좋다', '에도'],
#  ['하이라이트', '솔직하다', '죽이다', '이지', '부분', '좋다'],
#  ['에도', '듣다', '사람'],
#  ['시작'],
#  ['에도', '듣다', '사람'],
#  ['에도', '듣다', '사람'],
#  ['히히히', '히히히'],
#  ['도에', '듣다', '사람'],
#  ['에도', '들다'],
#  ['에도', '듣다', '사람', '개추', 'ㅋㅋ'],
#  ['듣다', '사람'],
#  ['에도', '듣다', '사람'],
#  ['죽이다'],
#  ['도에', '듣다'],
#  ['같이', '노래', '들다', '화이팅'],
#  ['에도', '듣다', '사람'],
#  ['하루', '듣다', '사람'],
#  ['이제', '이네요'],
#  ['에도', '듣다', '사람'],
#  ['오랜', '듣다', 'ㄹㅇ'],
#  ['신분'],
#  ['ㅈㄴ', '좋다'],
#  ['가제', '최근'],
#  ['이곡', '후반', '이후', '오다', '닿다', '노랗다'],
#  ['진짜',
#   '너무',
#   '많다',
#   '트랙리스트',
#   '적다',
#   '힘들다',
#   'TRACKLIST',
#   'BORN',
#   'HATER',
#   'EPIK',
#   'HIGH',
#   'GOTT',
#   'SIMON',
#   'DOMINIC',
#   'SMOKE',
#   'DYNAMIC',
#   'DUO',
#   '태지',
#   '창모',
#   'god',
#   'god',
#   'god',
#   'EK',
#   '주황색',
#   'ph',
#   '아침',
#   '홍원',
#   'Freak',
#   '보이',
#   'Freak',
#   'Like',
#   'Me',
#   'CAMO',
#   '쉬가릿',
#   '비비',
#   'Sunday',
#   '그루비',
#   'Sik',
#   '케이',
#   'Wifey',
#   'CAMO',
#   'Me',
#   'Like',
#   'Yuh',
#   'Jay',
#   'Park',
#   '시차',
#   'We',
#   'are',
#   '원재',
#   'Candy',
#   'Jay',
#   'Park',
#   'Boys',
#   'and',
#   'Girls',
#   'ZICO',
#   'Twlv',
#   'Blue',
#   'Moon',
#   '효린',
#   '창모',
#   '아무',
#   '노래',
#   'ZICO',
#   'Baby',
#   '자이언티',
#   'Outside',
#   '크러쉬',
#   'Day',
#   'Day',
#   '와이',
#   'WIN',
#   'WIn',
#   '와이',
#   '아프다',
#   '기리보이',
#   'Good',
#   'Times',
#   '팔로알토',
#   'SUPER',
#   'STAR',
#   'Dragon',
#   'HOP',
#   'ON',
#   '키보',
#   '이즈',
#   '뻔하다',
#   'JAY',
#   'PARK',
#   'Little',
#   'Bit',
#   '크러쉬',
#   'Right',
#   'Here',
#   'Right',
#   'Now',
#   'DPR',
#   'LIVE',
#   'Green',
#   'Horizon',
#   '펀치',
#   'Not',
#   'Sorry',
#   'Dean',
#   'Hug',
#   'Me',
#   '크러쉬',
#   'ON',
#   'AIR',
#   '보이',
#   'Selfmade',
#   'Orange',
#   '창모',
#   'Weathermen',
#   'MKIT',
#   'RAIN',
#   'LAMBO',
#   '미란',
#   'Tnf',
#   'BILL',
#   'STAX',
#   'SMF',
#   '창모',
#   '되다',
#   '대로',
#   '되다',
#   '개코',
#   '엉덩이',
#   '크다',
#   '그녀',
#   '릴러말즈',
#   '아낙네',
#   '송민호',
#   'ITX',
#   '질라',
#   'Achoo',
#   '미란',
#   'Bition',
#   'Way',
#   '애쉬',
#   '아일랜드',
#   '릴러말즈',
#   '붕붕',
#   '기다',
#   '뒤지다',
#   '버리다',
#   'AOMG',
#   'VVS',
#   '저스디스',
#   '그루비',
#   '머쉬',
#   '베놈',
#   'BAND',
#   'AMBITION',
#   '그늘',
#   '팔로알토',
#   'MULL',
#   'Keith',
#   'Ape',
#   'Call',
#   'Me',
#   '염따',
#   'Iffy',
#   'Sik',
#   'Martini',
#   'Blue',
#   'Flex',
#   '기리보이',
#   '키드',
#   '밀리',
#   '스윙스',
#   '노엘',
#   '귀감',
#   '콰이엇',
#   '사임',
#   '사임',
#   '쿠기',
#   '슈퍼',
#   '디아크',
#   'Amazing',
#   '에듀',
#   '케이티',
#   '키드',
#   'Have',
#   'Little',
#   'Fun',
#   'Sik',
#   '바다',
#   '기리보이',
#   '멜로디',
#   '애쉬',
#   '아일랜드',
#   'Good',
#   'Day',
#   'Ph',
#   '루피',
#   '키드',
#   '밀리',
#   'Summer',
#   'Paul',
#   'Blanco',
#   '어디',
#   '그램',
#   '지구',
#   '멸망',
#   '양승호',
#   '송민호',
#   '원래',
#   '이렇다',
#   '씨잼',
#   'Hyperreal',
#   '키드',
#   '밀리',
#   '재키',
#   '와이',
#   '지금',
#   '에듀',
#   '케이티',
#   '키드',
#   'So',
#   'Fast',
#   'CAMO',
#   'Rad',
#   'Museum',
#   'Get',
#   'Lifted',
#   '피제이',
#   '그대로',
#   '있다',
#   '돼다',
#   'Supreme',
#   'Team',
#   '달다',
#   '염따',
#   '딥플로우',
#   '팔로알토',
#   'Prime',
#   'Time',
#   '콰이엇',
#   '사이먼',
#   '도미',
#   '사이먼',
#   '도미',
#   '물음표',
#   '프라이머리',
#   'Oasis',
#   '크러쉬',
#   '지코',
#   'All',
#   'Wanna',
#   'Do',
#   'Jay',
#   'Park',
#   'Life',
#   'is',
#   'Wet',
#   'CAMO',
#   'Birthday',
#   'Ja',
#   'mezz',
#   'Make',
#   'Her',
#   'Dance',
#   '사이먼',
#   '도미',
#   'VENI',
#   'VIDI',
#   'VICI',
#   'ZICO',
#   'It',
#   'MA',
#   'Keith',
#   'Ape',
#   '카니발',
#   '기리보이',
#   '블랙',
#   '마에스트로',
#   '창모',
#   'SOJU',
#   'JAY',
#   'PARK',
#   'Helium',
#   '오케이션',
#   'Coupe',
#   '키드',
#   '밀리',
#   '생일',
#   'LOBONABEAT',
#   'WASABI',
#   'Bill',
#   'Stax',
#   'Gas',
#   '이센스',
#   'Rain',
#   'Showers',
#   '스윙스',
#   '연결고리',
#   '일리네어',
#   'Far',
#   'Post',
#   '윤하',
#   '탕아',
#   '뱃사공',
#   'Puzzle',
#   '와이',
#   '선빵',
#   '나플',
#   '비우다',
#   '창모',
#   '해시',
#   '스완',
#   '애쉬',
#   '아일랜드',
#   '담다',
#   '스윙스',
#   '키드',
#   '밀리',
#   '매드',
#   '크다',
#   'Jam',
#   'Butterfly',
#   'DPR',
#   'LIVE',
#   'No',
#   'Blueberries',
#   'DPR',
#   'IAN',
#   'Peach',
#   '레디',
#   '한강',
#   '콰이엇',
#   'RADIO',
#   '빈지노',
#   'Raniy',
#   'day',
#   '파테',
#   'MIA',
#   '미나',
#   'Downtown',
#   'Baby',
#   'BLOO',
#   'Meteor',
#   '창모',
#   'Hot',
#   'Summer',
#   '비프리',
#   'Bentley',
#   '염따',
#   '내일',
#   '오다',
#   '보이'],
#  ['믹싱임', '끄다', 'ㅋㅋㅋㅋㅋ'],
#  ['Ya',
#   'me',
#   'inscrib',
#   'espero',
#   'que',
#   'sea',
#   'algo',
#   'gratis',
#   'lo',
#   'hice',
#   'con',
#   'otro',
#   'aviso',
#   'tambi',
#   'gratis',
#   'para',
#   'trabajo',
#   'en',
#   'casa',
#   'fue',
#   'gratis',
#   'en',
#   'as',
#   'al',
#   'quer',
#   'an',
#   'cobrar',
#   'por',
#   'favor',
#   'si',
#   'fuera',
#   'el',
#   'caso',
#   'sean',
#   'bien',
#   'espec',
#   'ficos',
#   'digan',
#   'las',
#   'cosas',
#   'desde',
#   'un',
#   'principio',
#   'sino',
#   'fuera',
#   'el',
#   'caso',
#   'me',
#   'disculpo'],
#  ['좋다', '얼씨구'],
#  ['지니', '구독', '인데', '헬스할때', '지니', '틀다', '거틀', '고함', 'ㅋㅋ'],
#  ['말다',
#   '즐기다',
#   '모습',
#   '덩실',
#   '거립니',
#   '손가락',
#   '들다',
#   '제임슨',
#   '늦다',
#   '블로그',
#   '작업',
#   '너무',
#   '무료',
#   '같이',
#   '즐겁다',
#   '그리고',
#   '생각',
#   '보다',
#   '잊다',
#   '지내다',
#   '좋다',
#   '음악',
#   '모두',
#   '들다',
#   '있다',
#   '좋다',
#   'good',
#   'vibe'],
#  ['혹시', '나중', '오케이션', '노래', '믹스', '같다', '가능하다'],
#  ['혹시', '넘다', '국힙', '명곡', '믹스', '만들다'],
#  ['갔습니다', '달리다'],
#  ['댓글',
#   '자다',
#   '다는데',
#   '너무',
#   '좋다',
#   '있다',
#   '이어지다',
#   '부분',
#   '정말',
#   '자연스럽다',
#   '부드럽다',
#   '이어지다',
#   '댓글',
#   '차다',
#   '없다',
#   '좋다',
#   '영상',
#   '감사하다'],
#  ['최고'],
#  ['년생',
#   '플리',
#   '듣다',
#   '반하다',
#   '다른',
#   '듣다',
#   '짜리라니',
#   '너무',
#   '좋다',
#   '진심',
#   '넘다',
#   '축하',
#   '드리다'],
#  ['명인데', '만들다', '여수', '에서', '천안', '가다', '들다', '도착', '밉다', '치다', '플리'],
#  ['최애', '플리'],
#  ['수지', '빨리', '영상', '드랍', '해주다', 'ㅠㅠ'],
#  ['믹싱뭔', '지리다', '신나다'],
#  ['노래', '좋다', 'ㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎ'],
#  ['노래', '좋다', '구독', '박다', '전체', '알람', '켜놧음'],
#  ['존나', '좋다', '에전', '듣다', '페브릿곡', '다시', '듣다', '서다', '기억', '되다', '살아나다', '최고'],
#  ['남자', '좋아하다', '타입', '이구만', 'ㅎㅎㅎㅎ'],
#  ['트랙리스트', '까지', '적다', '친절하다'],
#  ['진짜', '듣기', '편하다'],
#  ['너무', '좋다'],
#  ['눈웃음', '너무', '예쁘다'],
#  ['진짜', '추억', '여행', '같다', '트랙', '이네', '보물', '이다'],
#  ['저희', '회사', '직원', '정도', '인데', '음악', '믹스', '기대하다'],
#  ['크다', '에서', '우연히', '들다', '너무', '좋다', '저장', '하고', '찾아듣다', 'ㅎㅎ'],
#  ['축하', '드리다'],
#  ['크다', '에서', '나오다', '찾다', '들다', '너무', '좋다', '계속', '되다', '같다'],
#  ['디엠', '줄다'],
#  ['가다', '가즈'],
#  ['보다', '헤이러'],
#  ['가면', '짜다', '축하'],
#  ['ㅋㅋㅋㅋㅋ', '처음', '이랑', '마지막', '이랑', '텐션', '차이', '너무', '웃기'],
#  ['메가믹스'],
#  ['가즈아', '트랙리스트', '기다리다', '있다'],
#  ['이제', '듣다', '같다'],
#  ['Cowbell', 'Warrior', 'Evil', 'Jordan', '추천'],
#  ['학원', '월말', '평가', '쓸다'],
#  ['광고', '존나', '많다'],
#  ['노래', '존나', '좋다', '따먹다'],
#  ['이건', '너무', '좋다'],
#  ['여기', '까지'],
#  ['멜론', '플리', '만들다', '안되다', 'ㅠㅠ'],
#  ['나오다', '노래', '가용', 'ㅠㅠ'],
#  ['Iggy',
#   'Azalea',
#   'Kream',
#   'feat',
#   'Tyga',
#   'Iggy',
#   'Azalea',
#   'Kream',
#   'feat',
#   'Tyga',
#   'Conner',
#   'Price',
#   'Haviah',
#   'Mighty',
#   'Trendsetter',
#   'Conner',
#   'Price',
#   'Haviah',
#   'Mighty',
#   'Trendsetter',
#   'Sugs',
#   'Archive',
#   'Tahiti',
#   'II',
#   'feat',
#   'Sugs',
#   'Sugs',
#   'Archive',
#   'Tahiti',
#   'II',
#   'feat',
#   'Sugs',
#   'Conner',
#   'Price',
#   'Killa',
#   'Violet',
#   'Conner',
#   'Price',
#   'Killa',
#   'Violet',
#   'Marshmello',
#   'Tyga',
#   'Chris',
#   'Brown',
#   'Light',
#   'it',
#   'Up',
#   'Marshmello',
#   'Tyga',
#   'Chris',
#   'Brown',
#   'Light',
#   'it',
#   'Up',
#   'alex',
#   'upadhyay',
#   'Billie',
#   'Eilish',
#   'Raga',
#   'alex',
#   'upadhyay',
#   'Billie',
#   'Eilish',
#   'Raga',
#   'Mc',
#   'Zaac',
#   'Desce',
#   'Pro',
#   'Play',
#   'Mc',
#   'Zaac',
#   'Desce',
#   'Pro',
#   'Play',
#   'Post',
#   'Malone',
#   'Cannot',
#   'Be',
#   'Sadder',
#   'Song',
#   'feat',
#   'Gunna',
#   'Post',
#   'Malone',
#   'Cannot',
#   'Be',
#   'Sadder',
#   'Song',
#   'feat',
#   'Gunna',
#   'Balming',
#   'Tiger',
#   'Armadillo',
#   'feat',
#   'Omega',
#   'Sapien',
#   'Byung',
#   'Un',
#   'Balming',
#   'Tiger',
#   'Armadillo',
#   'feat',
#   'Omega',
#   'Sapien',
#   'Byung',
#   'Un',
#   'Conner',
#   'Price',
#   'Killa',
#   'Amg',
#   'Conner',
#   'Price',
#   'Killa',
#   'Amg',
#   'villain',
#   'Stew',
#   'villain',
#   'Stew',
#   'Nate',
#   'Rose',
#   'Ollie',
#   'Joseph',
#   'Sheesh',
#   'Nate',
#   'Rose',
#   'Ollie',
#   'Joseph',
#   'Sheesh',
#   'Tyga',
#   'Taste',
#   'feat',
#   'Offset',
#   'Tyga',
#   'Taste',
#   'feat',
#   'Offset',
#   'Able',
#   'Heart',
#   'Too',
#   'Good',
#   'Able',
#   'Heart',
#   'Too',
#   'Good',
#   'Abhi',
#   'The',
#   'Nomad',
#   'JZAC',
#   'Kato',
#   'on',
#   'The',
#   'Track',
#   'KD',
#   'Money',
#   'Abhi',
#   'The',
#   'Nomad',
#   'JZAC',
#   'Kato',
#   'on',
#   'The',
#   'Track',
#   'KD',
#   'Money',
#   'Matt',
#   'Corman',
#   'Get',
#   'Out',
#   'The',
#   'Way',
#   'Matt',
#   'Corman',
#   'Get',
#   'Out',
#   'The',
#   'Way',
#   'Conner',
#   'Price',
#   'Tommy',
#   'Royale',
#   'Overnight',
#   'Conner',
#   'Price',
#   'Tommy',
#   'Royale',
#   'Overnight',
#   'Jack',
#   'Harlow',
#   'GHOST',
#   'Jack',
#   'Harlow',
#   'GHOST',
#   'Armani',
#   'White',
#   'Ap',
#   'Ferg',
#   'SILVER',
#   'TOOTH',
#   'Armani',
#   'White',
#   'Ap',
#   'Ferg',
#   'SILVER',
#   'TOOTH',
#   'Lakeyah',
#   'OG',
#   'Parker',
#   'In',
#   'Person',
#   'feat',
#   'Tyga',
#   'DJ',
#   'Drama',
#   'Lakeyah',
#   'OG',
#   'Parker',
#   'In',
#   'Person',
#   'feat',
#   'Tyga',
#   'DJ',
#   'Drama',
#   'Sophiya',
#   'Chief',
#   'Kief',
#   'Sophiya',
#   'Chief',
#   'Kief',
#   'Matt',
#   'Corman',
#   'In',
#   'My',
#   'Hands',
#   'Matt',
#   'Corman',
#   'In',
#   'My',
#   'Hands',
#   'bbno',
#   'piccolo',
#   'bbno',
#   'piccolo',
#   'Nic',
#   'Connor',
#   'Price',
#   'Still',
#   'Hot',
#   'Nic',
#   'Connor',
#   'Price',
#   'Still',
#   'Hot',
#   'Lo',
#   'Sneeze',
#   'feat',
#   'Kehlani',
#   'Lo',
#   'Sneeze',
#   'feat',
#   'Kehlani',
#   'Jack',
#   'Harlow',
#   'WHATS',
#   'POPPIN',
#   'Remix',
#   'feat',
#   'DaBaby',
#   'Tory',
#   'Lanez',
#   'Lil',
#   'Wayne',
#   'Jack',
#   'Harlow',
#   'WHATS',
#   'POPPIN',
#   'Remix',
#   'feat',
#   'DaBaby',
#   'Tory',
#   'Lanez',
#   'Lil',
#   'Wayne',
#   'Lil',
#   'Wayne',
#   'Shimmy',
#   'feat',
#   'Doja',
#   'Cat',
#   'Lil',
#   'Wayne',
#   'Shimmy',
#   'feat',
#   'Doja',
#   'Cat',
#   'Joyner',
#   'Lucas',
#   'Isis',
#   'feat',
#   'Logic',
#   'Joyner',
#   'Lucas',
#   'Isis',
#   'feat',
#   'Logic',
#   'Nicki',
#   'Minaj',
#   'FTCU',
#   'Nicki',
#   'Minaj',
#   'FTCU',
#   'Jack',
#   'Harlow',
#   'Lovin',
#   'On',
#   'Me',
#   'Jack',
#   'Harlow',
#   'Lovin',
#   'On',
#   'Me',
#   'Chain',
#   'Taylor',
#   'Young',
#   'Chain',
#   'Chain',
#   'Taylor',
#   'Young',
#   'Chain',
#   'Armani',
#   'White',
#   'BREATHE',
#   'freestyle',
#   'Armani',
#   'White',
#   'BREATHE',
#   'freestyle',
#   'Ktlyn',
#   'BIG',
#   'MAD',
#   'Ktlyn',
#   'BIG',
#   'MAD',
#   'Megan',
#   'Thee',
#   'Stallion',
#   'Do',
#   'It',
#   'on',
#   'the',
#   'Tip',
#   'feat',
#   'City',
#   'Girls',
#   'Hot',
#   'Girl',
#   'Meg',
#   'Megan',
#   'Thee',
#   'Stallion',
#   'Do',
#   'It',
#   'on',
#   'the',
#   'Tip',
#   'feat',
#   'City',
#   'Girls',
#   'Hot',
#   'Girl',
#   'Meg',
#   'Jack',
#   'Harlow',
#   'Tyler',
#   'Herro',
#   'Jack',
#   'Harlow',
#   'Tyler',
#   'Herro',
#   'Ktlyn',
#   'Blunty',
#   'Ktlyn',
#   'Blunty',
#   'Connor',
#   'Price',
#   'Nic',
#   'Riptide',
#   'Connor',
#   'Price',
#   'Nic',
#   'Riptide',
#   'Tyga',
#   'YG',
#   'Lil',
#   'Wayne',
#   'Brand',
#   'new',
#   'Tyga',
#   'YG',
#   'Lil',
#   'Wayne',
#   'Brand',
#   'new',
#   'Rubi',
#   'Rose',
#   'Hit',
#   'Yo',
#   'Dance',
#   'feat',
#   'Yella',
#   'Beezy',
#   'NLE',
#   'Choppa',
#   'Rubi',
#   'Rose',
#   'Hit',
#   'Yo',
#   'Dance',
#   'feat',
#   'Yella',
#   'Beezy',
#   'NLE',
#   'Choppa',
#   'Connor',
#   'Price',
#   'Armani',
#   'White',
#   'Million',
#   'Cash',
#   'Connor',
#   'Price',
#   'Armani',
#   'White',
#   'Million',
#   'Cash',
#   'Connor',
#   'Price',
#   'Siri',
#   'Chuck',
#   'Taylor',
#   'Connor',
#   'Price',
#   'Siri',
#   'Chuck',
#   'Taylor',
#   'Able',
#   'Heart',
#   'Worth',
#   'It',
#   'Able',
#   'Heart',
#   'Worth',
#   'It',
#   'LOVE',
#   'Daddy',
#   'Bought',
#   'It',
#   'LOVE',
#   'Daddy',
#   'Bought',
#   'It',
#   'Ktlyn',
#   'Boppin',
#   'Ktlyn',
#   'Boppin',
#   'Connor',
#   'Price',
#   'Matty',
#   'Beats',
#   'Receipts',
#   'Connor',
#   'Price',
#   'Matty',
#   'Beats',
#   'Receipts',
#   'Chainz',
#   'Lil',
#   'Wayne',
#   'Presha',
#   'Chainz',
#   'Lil',
#   'Wayne',
#   'Presha',
#   'Megan',
#   'Thee',
#   'Stallion',
#   'Thot',
#   'Shit',
#   'Megan',
#   'Thee',
#   'Stallion',
#   'Thot',
#   'Shit',
#   'Cal',
#   'Scruby',
#   'Faster',
#   'Cal',
#   'Scruby',
#   'Faster',
#   'Charmaine',
#   'WOO',
#   'Charmaine',
#   'WOO'],
#  ['힙합', '한국', '동요'],
#  ['빠뀨'],
#  ['노랗다', '안나'],
#  ['desce', 'pro', 'play'],
#  ['거슬리다', '없다', '플리', '존나', '오랜', '만이', 'skrr'],
#  ['여기', '주인', '지리다', '사랑'],
#  ['아아', '아아', '아아', '개지', '리노', '힙합', '이다', '이기'],
#  ['진짜', '비속어', '좋다'],
#  ['코너', '프라', '이스', '많이', '넣다', '잘알다'],
#  ['죄송하다', 'ㅅㅂ', '노래', '잘트', '고르다', '모음', '집중', '역대', '최고다'],
#  ['구독', '없다'],
#  ['웬만하다', '운동', '플리', '보다', '훨씬', '좋다', '감사하다'],
#  ['미국', '이렇다'],
#  ['나오다', '노래', '뭔가', 'ㅠㅠ', '싶다'],
#  ['뒤늦다',
#   '알다',
#   '정말',
#   '듣다',
#   '근데',
#   '여기',
#   '등록',
#   '되다',
#   'Play',
#   'List',
#   '멜론',
#   '그대로',
#   '기다',
#   '없다',
#   '아니다',
#   '찾다',
#   '끄다'],
#  ['맛집', '이네'],
#  ['아이스크림', '사르다', '마트', '살뻔'],
#  ['음악', '제목', '가수', '있다'],
#  ['정리',
#   'lggy',
#   'Azalea',
#   'Tyga',
#   'Kream',
#   'Connor',
#   'Price',
#   'Haviah',
#   'Mighty',
#   'Trendsetter',
#   'Connor',
#   'Price',
#   'Killa',
#   'Violet',
#   'Armani',
#   'White',
#   'BILLIE',
#   'EILISH',
#   'Armani',
#   'White',
#   'AP',
#   'Ferg',
#   'SILVER',
#   'TOOTH',
#   'Matt',
#   'Corman',
#   'IN',
#   'MY',
#   'HANDS',
#   'Nic',
#   'Connor',
#   'Price',
#   'Still',
#   'Hot',
#   'Jack',
#   'Harlow',
#   'Tory',
#   'Lanez',
#   'DaBaby',
#   'Lil',
#   'Wayne',
#   'Whats',
#   'Poppin',
#   '기석',
#   'Isis',
#   'Jack',
#   'Harlow',
#   'Tyler',
#   'Herro',
#   'Connor',
#   'Price',
#   'SIRI',
#   'Chuck',
#   'Taylor',
#   'Connor',
#   'Price',
#   'Matty',
#   'Beats',
#   'Receipts',
#   'Megan',
#   'Thee',
#   'Stallion',
#   'Thot',
#   'Shit',
#   'Bugus',
#   'Just',
#   'Know',
#   'Futuristic',
#   'Nolan',
#   'Own',
#   'It',
#   'Matt',
#   'Corman',
#   'Pay',
#   'Their',
#   'Rent',
#   'Joyner',
#   'Lucas',
#   'Timbaland',
#   'bands'],
#  ['지기'],
#  ['이거지'],
#  ['노래', '제목', '알다'],
#  ['작다', '바람', '있다', '처음', '광고', '넣다', '중간', '광고', '없다', '좋다'],
#  ['있다', '미적분', '문제', '원리', '합계', '돼다'],
#  ['이곡', '알다', '올드스쿨', '느낌', '너무', '좋다'],
#  ['운전', '거들다', '서하면', '난폭운전', '되다'],
#  ['잠깨'],
#  ['구나', '쇼츠'],
#  ['외힙', '플리', '믿다', '맡기다'],
#  ['지후', '듣다', '있다'],
#  ['아르마딜로', '외힙임'],
#  ['진짜', '너무', '좋다', '멜론', '없다', '너무', '많다', '슬프다'],
#  ['am', '허다'],
#  ['gang', '하자', 'skrrrrrr'],
#  ['노래', '진짜'],
#  ['운동', '최고'],
#  ['여자', '날리다', '사진', '어디서', '저장', '하나요', '프사', '고프다'],
#  ['시작', '노래', '제목', '알다', '있다'],
#  ['존나', '좋다'],
#  ['진짜', '미치다', '진짜', '최고', 'ㅋㅋㅋㅋㅋ'],
#  ['하고', '싶다', '정도', '겁나다', '타일', '트랜디', '드럼', '비트', 'bpm', '타석', '없다'],
#  ['번째', '노래', '예요'],
#  ['Good'],
#  ['싸다', '졸라', '좋다'],
#  ['가수', '제목', '이랑은', '어디서', '보다'],
#  ['덕분', '과제', '공부'],
#  ['존나', '음학', '까다롭다', '인데', '플리', '미치다'],
#  ['처음', '부터', '까지', '개맛', '도리'],
#  ['작곡', '부터', 'pusxx', 'axx', 'ㅋㅋㅋㅋㅋ'],
#  ['시험', '들다', '버리다'],
#  ['villion', 'stew', '저격'],
#  ['오다', '기분', '째지다'],
#  ['빅스', '한테', '이끌다'],
#  ['지리', '오지', '쩔다'],
#  ['최고다'],
#  ['뻐큐', '이름', '가요'],
#  ['레전드'],
#  ['빅스', '한테', '힙합', '노래', '틀다', '달라', '여기'],
#  ['오빠', '달다'],
#  ['외힙', '빠지다', '매일', '들다'],
#  ['진짜', '미치다', '같다'],
#  ['힙하', '힙해'],
#  ['운동', '들다', '감사하다'],
#  ['이렇게', '완벽하다', '취향', '외힙', '플리', '처음', '이에요'],
#  ['야무지다', '꽉꽉', '채우다'],
#  ['최고', '최고'],
#  ['뻑큐'],
#  ['멜론', '보스', '라운지', '검색', '거기', '플리', '천곡', '넣다', '들다', '오다'],
#  ['불혹', '여자', '부터', '여전하다', '힙합', '진짜', '최고'],
#  ['미국', '국가', '그거', '구나', 'ㅋㅋ'],
#  ['꾸다'],
#  ['진짜', '기만', '외힙', '플리', '본적', '들다', '적도', '없다', '조오오오오', '오다', '맛있다'],
#  ['푀이'],
#  ['음악', '너무', '좋다'],
#  ['PLAYLIST',
#   'Rainy',
#   'day',
#   '파테',
#   'GONE',
#   '릴러말즈',
#   'TOIL',
#   'RUN',
#   '릴러말즈',
#   'Panda',
#   'Gomm',
#   '검정색',
#   '하트',
#   'TOIL',
#   '릴러말즈',
#   '비다',
#   'Trip',
#   '릴러말즈',
#   'OHAYO',
#   'MY',
#   'NIGHT',
#   '디핵',
#   '파테',
#   '호랑이',
#   '소굴',
#   '기리보이',
#   '호구',
#   '기리보이',
#   '오늘',
#   '들어주다',
#   '감사하다',
#   'Thank',
#   'you',
#   'for',
#   'listening'],
#  ['야르'],
#  ['부터', '미치다'],
#  ['레이니', '데이', '듣다'],
#  ['릴러말즈', '띵곡', '작곡', '멀다'],
#  ['완전', '좋다'],
#  ['OHAYO', 'MY', 'NIGHT', '너무', '감사하다', '너무', '좋다', '노래', '플리', '들다', '어요'],
#  ['저장'],
#  ['계속', '노래', '부르다', '제목', '모르다', '감사하다'],
#  ['진짜', 'gone', '있다', '플리', '처음', '같다'],
#  ['자주', '오다'],
#  ['오하', '마이', '나이트', '띵곡'],
#  ['부분', '나오다', '멜로디', '외국', '팝송', '에서', '들다', '보다', '같다'],
#  ['있다', '부터', '합격'],
#  ['플리', '오타'],
#  ['취향'],
#  ['저가', '생각', '는걸', '모든', '사람', '좋다', '소원', '이다'],
#  ['Rainy', 'day', '부터', '미치다', 'ㅠㅠ'],
#  ['너무', '좋다'],
#  ['진짜', '겁나다', '좋다', '노래', '밖에', '없다'],
#  ['좋다', '영상', '만들다', '감사하다'],
#  ['헐다', 'ㅠㅠㅠ', '쩔어요', 'ㅠㅠㅠㅠ'],
#  ['감사하다', '기분', '많이', '풀리다'],
#  ['우와',
#   '넘다',
#   '좋다',
#   '이다',
#   '허다',
#   '회경',
#   '그렇게',
#   '살아가다',
#   '우비',
#   '이라도',
#   '좋다',
#   '부탁드리다'],
#  ['너무', '좋다', 'ohayo', 'my', 'night', '꽂히다'],
#  ['원래', '힙합', '자다', '듣다', '좋아하다', '모으다', 'ㅎㅎ', '자다', '들다', '좋다', '플리', '감사하다'],
#  ['파테', '썸네일', '이라', '바로', '클릭'],
#  ['좋아하다', 'set', '감사'],
#  ['검정색', '하트', '너무', '좋다', 'ㄹㅇ', 'ㅠㅠㅠ'],
#  ['알던띵곡', '인데', 'ㅋㅋ'],
#  ['릴러', '토일', '개다', '넘다', '좋다'],
#  ['미즈', '라는', '아티스트', '노래', '너무', '좋다'],
#  ['소굴', '재키', '파트', '들다', '수당'],
#  ['시험', '공부', '너무', '자다', '듣다', '가다'],
#  ['시험', '공부', '이어서', '서럽다', '죽다', '노래', '너무', '좋다', '나아지다', '감사하다'],
#  ['너무', '좋다', '항상', '듣다', '노래'],
#  ['가사'],
#  ['노래', '좋다'],
#  ['rainy', 'bay', '늘다', 'ㅈㄴ', '들다', '이제껏', '애쉬', '알다', 'ㅋㅋㅋ'],
#  ['요즘', '즐기다', '듣다', '모이다', '들다', '감사하다'],
#  ['플리', '그대로', '끼다'],
#  ['좋다'],
#  ['오다', '진짜', '좋아하다', '모으다', '놓다', '플리', '처음', '눈물', '같다', 'ㅠㅠ', '사랑'],
#  ['진짜', '좋아하다', '모으다', '같다', 'ㅠㅠㅠ', '감사', '드리다', '자주'],
#  ['맛있다'],
#  ['지금', '무슨', '생각', '생각'],
#  ['시작', '부터', 'rainy', 'day', '나오다', '부터', '힙잘알'],
#  ['전곡', '띵곡', '이네'],
#  ['𝐏𝐥𝐚𝐲𝐥𝐢𝐬𝐭',
#   '멜론',
#   '지니',
#   '스포티파이',
#   '플레이',
#   '리스트',
#   '옮기다',
#   'Loopy',
#   'WINNING',
#   '보이비',
#   '개코',
#   'PEP',
#   'Feat',
#   '정상',
#   'Khundi',
#   'Panda',
#   'Wild',
#   'Mess',
#   'Feat',
#   'XINSAYNE',
#   '신스',
#   'TANG',
#   'Feat',
#   '미란',
#   'Nasty',
#   'Kidz',
#   'SCP',
#   'Feat',
#   'PAXXWORD',
#   'BIG',
#   'Naughty',
#   'Kid',
#   'Milli',
#   'MMM',
#   'Khundi',
#   'Panda',
#   'Quagmire',
#   'Feat',
#   'The',
#   'Quiett',
#   '그냥',
#   '노창',
#   '기다',
#   '꼴통',
#   'Feat',
#   '창모',
#   '윤하',
#   '체리보이',
#   'Ima',
#   'Bad',
#   'Guy',
#   'sAewoo',
#   'Whatever',
#   'Feat',
#   '율음',
#   '키드',
#   '밀리',
#   '그냥',
#   '노창',
#   'The',
#   'Quiett',
#   'Raf',
#   'Sandou',
#   '보이비',
#   'Damndef',
#   'RDY',
#   'Will',
#   'Not',
#   'Fear',
#   'No',
#   'Face',
#   'No',
#   'Name',
#   'JAMM',
#   'MM',
#   'Nasty',
#   'Kidz',
#   'AIM',
#   'Lil',
#   'tachi',
#   '시대',
#   '미래',
#   'Khundi',
#   'Panda',
#   'Dustshine',
#   'huka',
#   'YAMA',
#   'Feat',
#   '스카이',
#   '민혁',
#   'huka',
#   'CALL',
#   'TONG',
#   'Feat',
#   '기백',
#   'CAMO',
#   'Round',
#   'Round',
#   'Feat',
#   '기리보이',
#   'CAMO',
#   '알다',
#   'Feat',
#   '창모',
#   'MBA',
#   '우리',
#   '얼마나',
#   'Feat',
#   'EK',
#   'Bola',
#   'Neal',
#   'BIG',
#   'Naughty',
#   'Kid',
#   'Milli',
#   'Revenge',
#   'Season',
#   'Feat',
#   'Chillin',
#   'Homie',
#   '공용',
#   '액세서리',
#   '상품',
#   '이벤트',
#   '진행',
#   '공식',
#   '홈페이지',
#   '스마트',
#   '스토어',
#   '인스타그램'],
#  ['듣다', '바로', '끄다'],
#  ['미치다', 'ㄹㅇ'],
#  ['Wild', 'mess', '노래방', '있다'],
#  ['씨잼', '좋다'],
#  ['오다', '국힙', '노래', '토나오다', '진짜'],
#  ['플레이', '리스트', '안되다'],
#  ['루피', '애플', '없다', 'ㅠㅠ'],
#  ['루피', '애플', '없다', 'ㅠㅠ'],
#  ['기다', '쩐다', 'ㅇㅇ'],
#  ['요즘', '빠지다', '플리', '듣다', '산다'],
#  ['신스'],
#  ['진짜',
#   '장난',
#   '아니다',
#   '지금',
#   '강아지',
#   '산책',
#   '듣다',
#   '진짜',
#   '디립니',
#   '진짜',
#   '감사하다',
#   '진짜',
#   '쌈뽕'],
#  ['한국', '힙합', 'imf', '라도', '터지다', '어쩌다', '지경', '나다'],
#  ['수퍼', '앨범', '플리', '넣다'],
#  ['되다'],
#  ['기다', '미치다', '고막', '살살', '녹다'],
#  ['꼴통'],
#  ['아니다', '신스', '개또', '인데', '진짜', '진자', '진짜', '진짜', '존나'],
#  ['루피', '이다'],
#  ['여기', '플리', '좋다', '요즘', '섞다', '너무', '유명하다', '않다'],
#  ['오늘'],
#  ['혹시', '보이비', '모음', '올려주다', '있다'],
#  ['루피', '빡센거', '알다', '쥐다'],
#  ['뭐임', '알다', '정상', '수가', '아니다'],
#  ['이집'],
#  ['동안', '플레이', '리스트', '운동', '텐션', '끌다', '올리다', '최고다'],
#  ['학교', '자다', '시간', '즐겁다'],
#  ['플레이',
#   '리스트',
#   '너무',
#   '감사하다',
#   '인생',
#   '고락',
#   '헤치다',
#   '나가다',
#   '있다',
#   '업리프팅',
#   '하고',
#   '진정',
#   '시키다',
#   '트랙',
#   '완벽하다',
#   '조합',
#   '이다',
#   '음악',
#   '나르다',
#   '믿다',
#   '응원',
#   '친구',
#   '처럼',
#   '능력',
#   '강하다',
#   '기억',
#   '해주다',
#   '노래',
#   '들다',
#   '마다',
#   '희망',
#   '로움',
#   '느끼다',
#   '플레이',
#   '리스트',
#   '당신',
#   '에게도',
#   '같다',
#   '위안',
#   '영감',
#   '있다',
#   '바라다'],
#  ['Jinsee', '때메', '성장', '오다'],
#  ['지기'],
#  ['좋다'],
#  ['랩퍼', '블릭', '차트'],
#  ['나다', '모르다', '추다', '잇다'],
#  ['랩퍼블릭', '웅장', '라인업', '이구만'],
#  ['포에버', 'megamix', '죽이다', 'remix'],
#  ['리믹스', '부분', '붙이다', '만들다', '가요'],
#  ['좋다'],
#  ['쟁이', '리믹스'],
#  ['구독', '좋다', '누르다'],
#  ['드디어', '찾다', '최애'],
#  ['베리', '최애', '한번', '부탁드리다', '죄송'],
#  ['음원',
#   '사이트',
#   '에서',
#   '발매',
#   '되다',
#   '리믹스',
#   '음원',
#   '유명하다',
#   '많이',
#   '모으다',
#   '보다',
#   '혹시',
#   '여기',
#   '빠지다',
#   '리믹스',
#   '버전',
#   '있다',
#   '댓글',
#   '남기다',
#   '타임',
#   '라인',
#   'Smoke',
#   'Remix',
#   '곡예사',
#   'Remix',
#   '사이렌',
#   'Remix',
#   'STAR',
#   'IS',
#   'BORN',
#   'Remix',
#   'Peace',
#   'Out',
#   'MEGA',
#   'MIX',
#   'BLUE',
#   'CHECK',
#   'REMIX',
#   '범퍼카',
#   'Remix',
#   'Remix',
#   '랄랄라',
#   'Remix',
#   'Pop',
#   'It',
#   'Remix',
#   'Daisy',
#   'Remix',
#   'Paranoid',
#   'Remix',
#   '대박',
#   '인생',
#   'Remix',
#   'VVS',
#   'GHR',
#   'Remix',
#   'Prime',
#   'Time',
#   'Remix',
#   '거북선',
#   'Remix',
#   '아프다',
#   'Band',
#   'Ver',
#   '몸매',
#   'Remix',
#   '알다',
#   '알다',
#   'Remix',
#   'DNA',
#   'Remix',
#   'BOY',
#   'Remix',
#   '한강',
#   'gang',
#   'megamix',
#   'Achoo',
#   'Remix',
#   'Swoosh',
#   'Flow',
#   'Remix',
#   '베이식',
#   'REMIX',
#   'Beverly',
#   'lls',
#   'Remix',
#   'Rain',
#   'Showers',
#   'Remix',
#   'REMIX'],
#  ['샤라',
#   '웃트',
#   '컬블릭',
#   '샤라',
#   '웃트',
#   '파우스트',
#   '괴테',
#   '샤라',
#   '웃트',
#   '마이클',
#   '타이',
#   '샤라',
#   '웃트',
#   '고흐',
#   '헐다',
#   '카수',
#   '그리고',
#   '이름',
#   '박다',
#   '한국',
#   '아인슈타인',
#   '노멀',
#   '엿먹',
#   '하지만',
#   '깁다',
#   '나마',
#   '여기',
#   '무덤',
#   '이라',
#   '적다',
#   '이르다',
#   '예술',
#   '전당',
#   '클럽',
#   '불다',
#   'maestro',
#   '그렇다',
#   '그렇게',
#   '불다',
#   '계급',
#   '으론',
#   '백건우',
#   '카라얀',
#   '정도',
#   '없다',
#   '딥플로우',
#   '섞다',
#   '자다',
#   '어울리다',
#   '치다',
#   '먹다',
#   '세컨',
#   '클래식',
#   '용어',
#   '악장',
#   '이렇다',
#   '이력',
#   '좋다',
#   '이다',
#   '피아노',
#   '있다',
#   '전용',
#   '오케스트라',
#   '보드',
#   '고장',
#   '맥북',
#   '내겐',
#   '위인',
#   '아니다',
#   '세종',
#   '연주'],
#  ['에도', '듣다', '사람'],
#  ['가사도', '차다', '잘쓰다'],
#  ['새끼', '오다'],
#  ['내겐', '위인', '아니다', '세종', '연주', '마에스트로', '가사', '미치다', '진짜'],
#  ['에게', '마에스트로', '오직'],
#  ['진짜', '마에스트로'],
#  ['안녕'],
#  ['창모', '칸예', '좋아하다', '보다'],
#  ['건가'],
#  ['에도듣는사람'],
#  ['시작'],
#  ['살때', '부터', '치다', '모야', 'ㅋㅋㅋ', '이라고', '해보다'],
#  ['택시', '기사', '아저씨', '부르다', '듣다', '오다'],
#  ['다시', '어도', '쩐다'],
#  ['아니다', '진짜', '레알', '세븐', '어쩌구', '모의', '마에스트로', '싸다', '간지', '차체'],
#  ['가다',
#   '슬슬',
#   '끝나다',
#   '이제',
#   '사회',
#   '나아가다',
#   '고등학생',
#   '학년',
#   '이여',
#   '마지막',
#   '마에스트로',
#   '함께',
#   '장식',
#   '도에',
#   '멀다',
#   '떠나다'],
#  ['바오', '쇼펜', '베르사체', '말다', '리카'],
#  ['택시', '기사', '보고오다', '사람', '거수'],
#  ['건희', '샤라', '되다'],
#  ['거만', '들다', '이제', '택시', '부르다', '할아버지', '생각나다'],
#  ['큐브릭', '파우스트', '괴테', '마이클', '타이', '고흐', '워홀', '쏘다'],
#  ['창모'],
#  ['근데', '이지', '나오다'],
#  ['듣다', '있다', '사람', '여기', '이다'],
#  ['마에스트로', '진짜', '동안', '계속', '들다', '정도', '개띵곡임'],
#  ['인스타', '택시', '기사', '보고', '오다', '개추'],
#  ['들다', '심장', '울리다', '배우다'],
#  ['대전', '축제', '라이브', '들다', '사람'],
#  ['마에스트로', '니까', '세븐', '나오다'],
#  ['끄다', '세븐', '마에스트로', '가창', '한테', '어딜', '비비다'],
#  ['택시', '기사', '할아버지', '보고오다', '사람', '없다'],
#  ['오다', '근데', '진짜', '지리'],
#  ['릴스', '에서', '택시', '기사', '아저씨', '부르다', '보고', '사람', '없다'],
#  ['최애', '파트'],
#  ['앨범', '커버', '존잘', '이네'],
#  ['근데', '다시', '보다', '앨범커버', '보다', '잘생기다'],
#  ['윤민수', '살때', '부터'],
#  ['힙합', '아니다', '음악', '같다'],
#  ['내일', '아빠', '용돈', '주다'],
#  ['부분', '피아노', '진짜', '미치다'],
#  ['미치다', 'ㅋㅋㅋㅋ'],
#  ['영계', '댓글', '보고', '오다'],
#  ['사실',
#   '수트',
#   '바지',
#   '보다',
#   '내다',
#   '치다',
#   '입다',
#   '점잖다',
#   '뜨다',
#   '그냥',
#   '외치다',
#   '버리다',
#   '쌓다',
#   '부자',
#   '거의',
#   '으론',
#   '젠틀',
#   '건희',
#   '칭호',
#   '노창',
#   '방금',
#   'line',
#   '듣다',
#   'fucked',
#   'up',
#   '허다',
#   'locked',
#   'up',
#   '되다',
#   '벌리다',
#   '리스크',
#   '첨벙',
#   '비닐',
#   '피아노',
#   '꿈꾸다',
#   '이다',
#   '그걸',
#   '살기',
#   '위해',
#   '숨구멍',
#   '알다',
#   '악보',
#   '따윈',
#   '동네',
#   '크다',
#   '구덩이',
#   '묻다',
#   '선언',
#   '자신',
#   'classic',
#   '박아',
#   '두다',
#   '내다',
#   'SONATA',
#   '늘다',
#   '오직',
#   '그것',
#   '따윈',
#   'never',
#   '생각',
#   '안해',
#   '비추다',
#   'all',
#   'of',
#   'the',
#   'lights',
#   '지금',
#   'symphony',
#   '악장',
#   '나다',
#   'fuck',
#   'Da',
#   'Capo',
#   '절대로',
#   '없다',
#   '돌아가다',
#   '박수',
#   'no',
#   'no',
#   '악장',
#   'play',
#   '할렐루야',
#   'Hash',
#   'hash',
#   'hash',
#   'hash',
#   'hashtag',
#   '벌다',
#   'Hash',
#   'hash',
#   'hash',
#   'hash',
#   'hashtag',
#   '좀처럼',
#   '나오다',
#   '않다',
#   '영재',
#   'Shout',
#   'out',
#   'to',
#   'Kubrick',
#   'Shout',
#   'out',
#   'to',
#   'Faust',
#   'Goethe',
#   'Shout',
#   'out',
#   'to',
#   'Michael',
#   'Tyson',
#   'Shout',
#   'out',
#   'to',
#   'Gogh',
#   'Warhol',
#   'Casso',
#   '그리고',
#   '이름',
#   '박다',
#   'whoa',
#   '한국',
#   'Einstein',
#   'normal',
#   '엿먹',
#   '하지만',
#   'don',
#   'give',
#   'fuck',
#   'Son',
#   'ma',
#   'fuck',
#   'you',
#   'up',
#   '여기',
#   '무덤',
#   '이라',
#   '적다',
#   '이르다',
#   '예술',
#   '전당',
#   'club',
#   '불다',
#   'maestro',
#   '그렇다',
#   '그렇게',
#   '불다',
#   '계급',
#   '으론',
#   '백건우',
#   '카라얀',
#   'work',
#   '정도',
#   '없다',
#   'Deepflow',
#   '끄다',
#   '섞다',
#   '자다',
#   '어울리다',
#   '치다',
#   '먹다',
#   'second',
#   'round',
#   'classic',
#   '용어',
#   '악장',
#   '이렇다',
#   '이력',
#   '좋다',
#   '이다',
#   'piano',
#   '오다',
#   'rap',
#   '있다',
#   '전용',
#   'orchestra',
#   '보드',
#   '고장',
#   'MacBook',
#   '내겐',
#   '위인',
#   '아니다',
#   '세종',
#   '연주'],
#  ['모형', '노래', '진짜', '정말', '너무', '부르다', '존경', '모형'],
#  ['인스트', '미치다'],
#  ['전역', '하자'],
#  ['노래', '들다', '마다', '기철', '드립', '떠오르다'],
#  ['편집', 'ㄷㄷ'],
#  ['창모', '누구', '에나', '좋다', '들리다', '목소리', '있다', '같다'],
#  ['도에', '듣다', '사람'],
#  ['돈벌',
#   '시간',
#   '처음',
#   '들다',
#   '생각나다',
#   '마에스트로',
#   '먼저',
#   '들다',
#   '지리다',
#   'ㅋㅋㅋㅋ',
#   '마에스트로',
#   '진짜',
#   '영원하다',
#   '명곡',
#   '이지'],
#  ['진짜', '소름', '돋다', '처음', '들다', '전율', '이란'],
#  ['레전드'],
#  ['전설'],
#  ['오다', '너무', '좋다'],
#  ['진짜', '피아노', '오토튠', '지리다', '라임', '다스려지다', '마에스트로', 'ㅈㄴ', '듣기', '좋다'],
#  ['듣다', '공부'],
#  ['드디어', '떳다'],
#  ['근데', '다시', '보다', '앨범커버', '보다', '잘생기다'],
#  ['오다', '마에스트로', 'ㄷㄷㄷ'],
#  ['세다',
#   '호미',
#   'Where',
#   'are',
#   'you',
#   'from',
#   'Untell',
#   'Gang',
#   'Gang',
#   'Gang',
#   'Feat',
#   '박재범',
#   'Lil',
#   'Moshpit',
#   'Fleeky',
#   'Bang',
#   'Drop',
#   'It',
#   'Feat',
#   '이영지',
#   '블라세',
#   'SMF',
#   'Prod',
#   'Czaer',
#   '창모',
#   'DDKD',
#   'Feat',
#   'JUSTHIS',
#   '다이나믹',
#   '듀오',
#   '허성',
#   'Huh',
#   'Feat',
#   'CHANGMO',
#   'Fleeky',
#   'Bang',
#   'Feat',
#   'Tabber',
#   '다이나믹',
#   '듀오'],
#  ['진짜', '사랑', '사랑', '사랑'],
#  ['원하다'],
#  ['취향', '저격'],
#  ['오다', '플레이', '리스트', '제목', '씹다', 'mz', '스럽다', '개패', '싶다', 'ㅋㅋ', '칭찬', '이다'],
#  ['다이나믹듀오', '죽이다', '좋다'],
#  ['오다', '취향', '저격', '찾다'],
#  ['블라세', 'Drop', 'it', '너무', '좋다'],
#  ['수퍼', '앨범', '플리', '만들다'],
#  ['뜨다', '좋다', '너무', '좋다'],
#  ['듣기', '좋다'],
#  ['노래', '과고', '씨발', 'ㅋㅋㅋㅋ', '넘다'],
#  ['smf', '창모', '노래', '인데', '언텔', '영상', '에는', '나오다'],
#  ['애기', '아니다', '배틀', 'ㅋㅋㅋㅋ', '군대', '다녀오다', '이런'],
#  ['탐라', '써주다', '용용'],
#  ['크다'],
#  ['찾다', '최애', '바로', '구독', '박다', '드릴', '도리'],
#  ['진짜', '힙합', '자다', '아시', '이네', '이렇다', '플레이', '리스트', '찾기', '힘드다'],
#  ['진짜', '알다', '아쉽다', '따름', '이다'],
#  ['개인',
#   '다른',
#   '노래',
#   '전부',
#   '마지막',
#   '나오다',
#   '끝나다',
#   '여기다',
#   '마지막',
#   '숨다',
#   '쉬다',
#   '어질다',
#   '빠르다',
#   '필살기',
#   '넣다',
#   '버리다',
#   '질리다',
#   '않다',
#   '너무',
#   '좋다',
#   '붕붕',
#   '순위',
#   'ㅜㅠ'],
#  ['도맘때'],
#  ['오랜', '다시', '듣다', '너무', '좋다', '음악', '에서', '위안', '용기', '얻다'],
#  ['기다', '천재'],
#  ['진짜', '언제', '들다', 'goat'],
#  ['히트', '나오다', '다시', '들다'],
#  ['기다', '벌스', '지금', '들다', '전혀', '어색하다', '아쉽다', '않다'],
#  ['설레다', '최신', '댓글'],
#  ['진짜', '듣다'],
#  ['케이', '라이브', '에서도', '정도'],
#  ['그루비', '비트', '린다', '얘넨', '재임'],
#  ['비트', 'ㄹㅇ', '미치다'],
#  ['어디',
#   '가다',
#   '모르다',
#   '저스월비',
#   '가능',
#   '따르다',
#   '흐르다',
#   '밉다',
#   '걸음걸이',
#   '팔자',
#   '무한대',
#   '그렇다',
#   '닮다',
#   '질리',
#   '따르다',
#   '영혼',
#   '동선',
#   '임파',
#   '사이',
#   '스페이스',
#   '보다',
#   '파서',
#   '파리',
#   '계속',
#   '돼다',
#   '누가',
#   '빠지다',
#   '이글이글',
#   '기름',
#   '부어',
#   '흘리다',
#   '지금',
#   '리듬',
#   '빙글빙글',
#   '하루',
#   '이틀',
#   '믿다',
#   '칠흑',
#   '믿음'],
#  ['처음', '나오다', '영어', '나래', '션좀', '적다', '계시다', 'ㅠㅠ'],
#  ['솔직하다', '지금', '없다', '있다', '인정', '하고'],
#  ['달에', '들다', '사람'],
#  ['에도', '듣다', '하트', 'ㄱㄱ'],
#  ['지금', '듣다', '사람', '진짜', '없다'],
#  ['노래', '린다'],
#  ['나중', '달았쥬', '이기다', '버리다'],
#  ['노래', '나오다', '태어나다', '올해', '초등학교', '입학', 'ㄷㄷ'],
#  ['Black',
#   '에서',
#   'brown',
#   'Brown',
#   '에서',
#   'yellow',
#   'Yellow',
#   '에서',
#   'white',
#   'White',
#   '에서',
#   'what',
#   '가다',
#   'ㄹㅈㄷ'],
#  ['국힙', '싫어하다', '노래', '만큼은', '싫어하다'],
#  ['진짜', '공부', '듣다', '힘들다'],
#  ['들다', '이제', '군대', '가다', '듣다', '사람', '모두', '화이팅'],
#  ['좋아하다', '사람', '플레이', '리스트', '무조건', '있다', '노래'],
#  ['이번', '연습'],
#  ['이건', '진짜', '지금', '들다', '레전드'],
#  ['피아노',
#   '소리',
#   '그렇다',
#   '마지막',
#   '많이',
#   '나오다',
#   '그렇다',
#   '살짝',
#   '에미넴',
#   '고질라',
#   '느낌',
#   '나다',
#   'ㅋㅋ',
#   '쉬다',
#   '부분',
#   '비슷하다'],
#  ['브금', 'ㅋㅋ'],
#  ['나중', '달다'],
#  ['댓글', '애벌', '렙니', '그거', '보고', '겁나다', '웃다', 'ㅋㅋㅋㅋ'],
#  ['좋다', '심심하다', '들다'],
#  ['듣기', 'ㅎㅎ'],
#  ['보다', '사람', '누르다'],
#  ['보다', '사람'],
#  ['보다'],
#  ['붕붕'],
#  ['듣다', '사람'],
#  ['오이', '보다', '사람', '아직도', '있다'],
#  ['새해', '많이', '받다'],
#  ['노래'],
#  ['밉다', '출신', '아니다', '존나', '나대다', '시발', '그냥', 'ㅋㅋㅋ'],
#  ['오랜', '듣넹', 'ㅎㅎ'],
#  ['레진드'],
#  ['듣기'],
#  ['발목', '족쇄', '풀다'],
#  ['지금', '댓글달다', '독자', '모으다'],
#  ['플로우', '지리다'],
#  ['히트', '보고', '사람'],
#  ['아이구', '천식', '케이', '여기다', '이상하다'],
#  ['맨날', '있다', '붕붕'],
#  ['설마', '에도', '하트', '달다'],
#  ['기억나다', '들다', '쾌감', '위인'],
#  ['날듣고있는분'],
#  ['노래', '축제', '나가다', '사람'],
#  ['에도', '듣다', '사람'],
#  ['에도', '듣다', '사람'],
#  ['ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ'],
#  ['힙합',
#   '뜨다',
#   '해주다',
#   '이라',
#   '애정',
#   '많다',
#   '그때',
#   '부터',
#   '지금',
#   '까지',
#   '계속',
#   '힙합',
#   '매우',
#   '사랑',
#   '하고',
#   '있다'],
#  ['𝐏𝐥𝐚𝐲𝐥𝐢𝐬𝐭',
#   '𝐓𝐢𝐦𝐞𝐥𝐢𝐧𝐞',
#   '스포티파이',
#   'Spotify',
#   '에서',
#   '다시',
#   '듣기',
#   '유튜브',
#   '뮤직',
#   'YouTube',
#   'Music',
#   '에서',
#   '다시',
#   '듣기',
#   'Eminem',
#   'Without',
#   'Me',
#   'Terror',
#   'Squad',
#   'Fat',
#   'Joe',
#   'Lean',
#   'Back',
#   'Cupid',
#   'Cupid',
#   'Shuffle',
#   'Dr',
#   'Dre',
#   'Snoop',
#   'Dogg',
#   'The',
#   'Next',
#   'Episode',
#   'Soulja',
#   'Boy',
#   'Kiss',
#   'Me',
#   'Thru',
#   'The',
#   'Phone',
#   'Soulja',
#   'Boy',
#   'Crank',
#   'That',
#   'Cent',
#   'Just',
#   'Lil',
#   'Bit',
#   'Justin',
#   'Timberlake',
#   'Timbaland',
#   'SexyBack',
#   'Bring',
#   'Em',
#   'Out',
#   'Far',
#   'East',
#   'Movement',
#   'Like',
#   'Dr',
#   'Dre',
#   'Eminem',
#   'What',
#   'The',
#   'Difference',
#   'Black',
#   'Eyed',
#   'Peas',
#   'Let',
#   'Get',
#   'It',
#   'Started',
#   'Cent',
#   'In',
#   'Da',
#   'Club',
#   'MIMS',
#   'Like',
#   'This',
#   'Soulja',
#   'Boy',
#   'Soulja',
#   'Girl',
#   'Flo',
#   'Rida',
#   'Pain',
#   'Low',
#   'Chris',
#   'Brown',
#   'Pain',
#   'Kiss',
#   'Kiss',
#   'MIMS',
#   'This',
#   'Is',
#   'Why',
#   'Hot',
#   'Eve',
#   'Who',
#   'That',
#   'Girl',
#   'Cent',
#   'Olivia',
#   'Candy',
#   'Shop',
#   'Rihanna',
#   'JAY',
#   'Umbrella',
#   'Pit',
#   'Bull',
#   'Trina',
#   'Go',
#   'Girl',
#   'Cent',
#   'Dr',
#   'dre',
#   'Snoop',
#   'Dogg',
#   'Still',
#   'Cent',
#   'Disco',
#   'Inferno',
#   'Eminem',
#   'Lose',
#   'Yourself',
#   'Usher',
#   'Lil',
#   'Jon',
#   'Yeah',
#   'Yung',
#   'Joc',
#   'NITTI',
#   'It',
#   'Goin',
#   'Down',
#   'Missy',
#   'Elliott',
#   'Get',
#   'Ur',
#   'Freat',
#   'On',
#   'Eminem',
#   'Shake',
#   'That',
#   'JAY',
#   'Empire',
#   'State',
#   'Of',
#   'Mind',
#   'Timbaland',
#   'The',
#   'Way',
#   'Are',
#   'Black',
#   'Eyed',
#   'Peas',
#   'Boom',
#   'Boom',
#   'Pow',
#   'Cent',
#   'Justin',
#   'Timberlake',
#   'Ayo',
#   'Technology',
#   'Missy',
#   'Elliott',
#   'Lose',
#   'Control',
#   'Unk',
#   'Walk',
#   'It',
#   'Out',
#   'Unk',
#   'Step',
#   'Black',
#   'Eyed',
#   'Peas',
#   'My',
#   'Humps',
#   'Petty',
#   'Ricky',
#   'Your',
#   'Body',
#   'Nas',
#   'Can',
#   'Nelly',
#   'Kelly',
#   'Rowland',
#   'Dilemma',
#   'Ne',
#   'Yo',
#   'Because',
#   'Of',
#   'You'],
#  ['헬린', '피티', '받다', '관장', '틀다', '달라'],
#  ['근데', 'without', 'me', '가다', '배다'],
#  ['생입니다', '좋다'],
#  ['노래', '듣다', '헬스장', '에서', '쉐도우', '쫒다', '나다'],
# ...
#   'big',
#   'We',
#   'on',
#   'fire',
#   '이건',
#   '우릴',
#   '올라가다',
#   '매일',
#   '오다',
#   '꼭대기',
#   'My',
#   'mama',
#   'told',
#   'me',
#   'can',
#   'be',
#   'something',
#   'big',
#   'We',
#   'on',
#   'fire',
#   '이건',
#   '우릴',
#   '멈추다',
#   '있다',
#   '스톱',
#   '사인',
#   'SCH',
#   'YEL',
#   'he',
#   'gon',
#   'do',
#   'spin',
#   '한국',
#   '남자',
#   '래퍼',
#   '미녀',
#   '왜냐면',
#   '마주치다',
#   'sleep',
#   '뭐라다',
#   '하든',
#   '위너',
#   '근데',
#   'YELLIN',
#   '알다',
#   'Team',
#   '인생',
#   '천만',
#   '관람',
#   '무비',
#   '그냥',
#   '유튜브',
#   '있다',
#   '클립',
#   '역시',
#   'ball',
#   'baby',
#   '그래서',
#   '자다',
#   '보다',
#   'ballin',
#   '같다',
#   'callin',
#   'me',
#   'ha',
#   '받다',
#   '졸림',
#   'No',
#   'kizzy',
#   'no',
#   'kidding',
#   '나르다',
#   '앞서다',
#   'sliding',
#   'Fleeky',
#   'Bang',
#   '빠지다',
#   'party',
#   '소리치다',
#   'Gang',
#   'gang',
#   'gang',
#   'Aye',
#   'hop',
#   'out',
#   '축구',
#   '아니다',
#   'ball',
#   '가방',
#   '귀신',
#   '같이',
#   '갑자기',
#   '튀어나오다',
#   'yeah',
#   'pop',
#   'out',
#   '걔네',
#   '거짓말',
#   '치다',
#   '니까',
#   '전부',
#   '들리다',
#   '사탄',
#   '넘다',
#   '맵다',
#   '불닭',
#   'taste',
#   'sweet',
#   'like',
#   '사탕',
#   '올라가다',
#   '매일',
#   '오다',
#   '꼭대기',
#   'My',
#   'mama',
#   'told',
#   'me',
#   'can',
#   'be',
#   'something',
#   'big',
#   'We',
#   'on',
#   'fire',
#   '이건',
#   '우릴',
#   '올라가다',
#   '매일',
#   '오다',
#   '꼭대기',
#   'My',
#   'mama',
#   'told',
#   'me',
#   'can',
#   'be',
#   'something',
#   'big',
#   'We',
#   'on',
#   'fire',
#   '이건',
#   '우릴'],
#  ['노래', '나오다', '피모', '낭만', '이다'],
#  ['돌아오다'],
#  ['피파',
#   '모바일',
#   '경기',
#   '한판',
#   '끝나다',
#   '노래',
#   '나오다',
#   '따르다',
#   '부르다',
#   '돼다',
#   '그냥',
#   '듣기',
#   '시절',
#   '낭만',
#   '생각나다'],
#  ['하나', '듣다', '차서', '템페스트', '악장', '시작', '클래식', '플리', '만들다'],
#  ['피파', '노랭'],
#  ['솔직하다', '피아노', '사운드', '너무', '찰지다', '맛있다'],
#  ['엄청나다'],
#  ['엄청나다'],
#  ['학년', '진경', '도의', '전설', '이다', '진짜', 'ㅋㅋ'],
#  ['플리',
#   '키뱅',
#   '라이브',
#   '에선',
#   '약간',
#   '소리',
#   '먹히다',
#   '그렇다',
#   '느낌',
#   '있다',
#   '음원',
#   '에서는',
#   '지리',
#   'ㄹㅇㅋㅋ'],
#  ['모야', '제발', '다시', '돌아오다'],
#  ['yo', 'fleekybang', '우슬', '라임'],
#  ['군대', '에서', '듣다', '인데', 'ㅈㄴ', '째다'],
#  ['올라가다'],
#  ['우즈', '사람', '있다'],
#  ['피파', '모바일', '브금', '이노'],
#  ['듣다', '있다', '사람'],
#  ['피파', '떠오르다', 'ㅋㅋㅋㅋㅋ'],
#  ['지우', '돌아오다'],
#  ['피파',
#   '옛날',
#   '그렇게',
#   '삐뚤어지다',
#   'FC',
#   '모바일',
#   '말고',
#   '피파',
#   '돌아오다',
#   '돼다',
#   '제발',
#   '진짜',
#   '진짜',
#   '제발',
#   '열심히',
#   '이름',
#   '피파',
#   '모바일',
#   '바꾸다',
#   '노래',
#   '노래',
#   '바꾸다',
#   '제발'],
#  ['이곡', '놀토', '나가다', '맞추다'],
#  ['모이다'],
#  ['피파', '생각나다', '사람'],
#  ['듣다', '사람'],
#  ['파파', '모바일', '알다', '사람', '바로', '좋다', '박다', '댓글', '달자'],
#  ['개삽', '레전드'],
#  ['피파',
#   '노래',
#   '게임',
#   '틀때',
#   '마다',
#   '처음',
#   '들리다',
#   '는걸',
#   '반년',
#   '이상',
#   '우려',
#   '먹다',
#   '점점',
#   '듣기',
#   '힘들다',
#   '오랜',
#   '들다',
#   '좋다'],
#  ['피파', '노래'],
#  ['느금마'],
#  ['젠장', '이제', '아니다', '피파', '브금', '처럼', '들다', '버리다'],
#  ['피파', '알다', '노래'],
#  ['노래', '좋다'],
#  ['노래', '추억', '계속', '허다', '날팀', '호돈', '사기', '이다', '이벤트', '에서', '계속', '주다'],
#  ['ㅈㄴ', '그리다'],
#  ['fifa'],
#  ['에도', '듣다', '사람', '여기', '모이다'],
#  ['오랜', '만이', '시절', '피모', '브금'],
#  ['피파', '모바일', '토츠때', '나오다', '좋다'],
#  ['일루', '모이다'],
#  ['에도', '듣다', '사람'],
#  ['지다',
#   '들이다',
#   '노래',
#   '만들다',
#   '보다',
#   '노래',
#   '아니다',
#   '여기',
#   '노래',
#   '자기',
#   '스타일',
#   '아니다',
#   '평가'],
#  ['이륙',
#   'Take',
#   'off',
#   '기세',
#   '마치',
#   '폭포',
#   '실패',
#   'no',
#   'more',
#   'Victory',
#   'or',
#   'nope',
#   '관중',
#   '반짝',
#   '메이데이',
#   '쉬다',
#   'toss',
#   '작년',
#   'peace',
#   'out',
#   '에서부터',
#   '차리다',
#   '식사',
#   '허다',
#   '성급하다',
#   '성공',
#   '쇄도',
#   '공간',
#   'Through',
#   'pass',
#   'got',
#   'the',
#   'UK',
#   'accent',
#   'But',
#   'in',
#   'KR',
#   '시작',
#   '골방',
#   '이다',
#   '이제',
#   '우린',
#   'worldwide',
#   'Fosho',
#   'For',
#   'real',
#   'man',
#   '절대',
#   '덤벙',
#   '과거',
#   '컴컴하다',
#   '미랜',
#   '번쩍',
#   '딱딱하다',
#   '가지',
#   '빡빡',
#   '머리',
#   '벌써',
#   '나인',
#   'Baby',
#   'don',
#   'worry',
#   '이제',
#   '전성기',
#   '나이',
#   '나잇',
#   '쉬다',
#   '올라타다',
#   'Look',
#   'just',
#   'shootin',
#   'like',
#   '손흥민',
#   '처럼',
#   'can',
#   'be',
#   'the',
#   'top',
#   'boy',
#   '함성',
#   '소리',
#   '덮다',
#   '치다',
#   '기회',
#   '오다',
#   'can',
#   'do',
#   'better',
#   '기회',
#   '오다',
#   'touch',
#   'the',
#   'sky',
#   '그렇다',
#   '닿다',
#   '대기권',
#   '바닥',
#   '떨어지다',
#   '없다',
#   'Check',
#   'my',
#   'profile',
#   '말고는',
#   '재미없다',
#   '패배',
#   '있다',
#   '더욱더',
#   '단단하다',
#   '배우다',
#   '거지',
#   '다른',
#   '지금',
#   '이기다',
#   '에만',
#   '쏟다',
#   '그릴',
#   '각자',
#   '자리',
#   '윤하',
#   'everywhere',
#   '여기저기',
#   '있다',
#   '계속',
#   'Yeah',
#   'never',
#   'stop',
#   '괴롭다',
#   'Like',
#   'box',
#   'to',
#   'box',
#   'NO',
#   '트랩',
#   '배다',
#   '드릴',
#   '상관없다',
#   '뱉다',
#   'Cuz',
#   'MC',
#   '진짜',
#   '래퍼',
#   '유행',
#   '같다',
#   '타지',
#   '않다',
#   '여름',
#   '가을',
#   '겨울',
#   '제철',
#   'yo',
#   'big',
#   'brother',
#   '올라가다',
#   '너무',
#   '높다',
#   '어떡하다',
#   '우린',
#   '떨어지다',
#   '절대',
#   '돼다',
#   '겁쟁이',
#   '언제나',
#   '멋대로',
#   '멀다',
#   '눈앞',
#   'Just',
#   'do',
#   'it',
#   'my',
#   'brother',
#   '이루다',
#   '위해',
#   '목표',
#   '생각',
#   '일단',
#   '펼치다',
#   '치다',
#   '번만',
#   '보다',
#   '에는',
#   '나오다',
#   '이번',
#   '기회',
#   'fly',
#   '올라가다',
#   '매일',
#   '오다',
#   '꼭대기',
#   'My',
#   'mama',
#   'told',
#   'me',
#   'can',
#   'be',
#   'something',
#   'big',
#   'We',
#   'on',
#   'fire',
#   '이건',
#   '우릴',
#   '올라가다',
#   '매일',
#   '오다',
#   '꼭대기',
#   'My',
#   'mama',
#   'told',
#   'me',
#   'can',
#   'be',
#   'something',
#   'big',
#   'We',
#   'on',
#   'fire',
#   '이건',
#   '우릴',
#   '실패',
#   '절대',
#   '두렵다',
#   '않다',
#   '넘어지다',
#   '포기',
#   '따윈',
#   '알다',
#   '막다',
#   '장애물',
#   '있다',
#   '멈칫',
#   '않다',
#   '깊다',
#   '들이마시다',
#   '이륙',
#   '준비',
#   '날다',
#   '결국',
#   '트로피',
#   '거머쥐',
#   '나서다',
#   '기회',
#   '바로',
#   '잡다',
#   '꿈꾸다',
#   '오다',
#   '감다',
#   '들리다',
#   '함성',
#   '소리',
#   '누가',
#   '뭐라다',
#   '오직',
#   '목표',
#   '하나',
#   '황소',
#   '고집',
#   '플리',
#   '키뱅',
#   '호미',
#   '윤하',
#   '블라세',
#   '키츠',
#   '요지',
#   '우리',
#   '국가대표',
#   '귀엽다',
#   '마치',
#   '슛돌이',
#   '몸싸움',
#   '내버리다',
#   '멀리',
#   '만약',
#   '들다',
#   '벤치',
#   '클리어',
#   '귓가',
#   '이명',
#   '대신',
#   '울리다',
#   '승리',
#   '나팔',
#   '소리',
#   'La',
#   'lala',
#   'lalala',
#   '넘기다',
#   'bad',
#   'vibes',
#   '다섯',
#   '훈련',
#   'my',
#   'time',
#   'is',
#   'go',
#   'ticking',
#   '구르다',
#   '매일',
#   '박아',
#   'taking',
#   'that',
#   'risky',
#   '어차피',
#   '아니다',
#   '있다',
#   '고생',
#   '다음',
#   '에는',
#   '최고',
#   '아니다',
#   'no',
#   '자신감',
#   '앞뒤',
#   '가리다',
#   'beat',
#   'it',
#   'LIFE',
#   'Yo',
#   'pass',
#   'that',
#   'ball',
#   'hit',
#   'the',
#   'score',
#   'right',
#   'Ye',
#   'It',
#   'time',
#   'to',
#   'get',
#   'this',
#   'uh',
#   '얘기',
#   'Was',
#   'long',
#   'flight',
#   '포기',
#   '오다',
#   '여기',
#   '다시',
#   '부어',
#   '전부',
#   'bet',
#   'my',
#   'whole',
#   'life',
#   'My',
#   'foot',
#   'on',
#   'the',
#   'gas',
#   '오르다',
#   'MIC',
#   '주다',
#   'pass',
#   'out',
#   'or',
#   'die',
#   'Ye',
#   'sturdy',
#   'sturdy',
#   'woo',
#   'too',
#   'naughty',
#   'naughty',
#   '보이다',
#   '드디어',
#   '성공',
#   'So',
#   'mom',
#   'don',
#   'worry',
#   'worry',
#   'Skrtin',
#   'skrtin',
#   'LIFE',
#   '있다',
#   '여기저기',
#   '따내다',
#   'Trophies',
#   '없다',
#   'It',
#   'time',
#   'to',
#   'get',
#   'this',
#   'money',
#   'money',
#   '올라가다',
#   '매일',
#   '오다',
#   '꼭대기',
#   'My',
#   'mama',
#   'told',
#   'me',
#   'can',
#   'be',
#   'something',
#   'big',
#   'We',
#   'on',
#   'fire',
#   '이건',
#   '우릴',
#   '올라가다',
#   '매일',
#   '오다',
#   '꼭대기',
#   'My',
#   'mama',
#   'told',
#   'me',
#   'can',
#   'be',
#   'something',
#   'big',
#   'We',
#   'on',
#   'fire',
#   '이건',
#   '우릴',
#   '멈추다',
#   '있다',
#   '스톱',
#   '사인',
#   'SCH',
#   'YEL',
#   'he',
#   'gon',
#   'do',
#   'spin',
#   '한국',
#   '남자',
#   '래퍼',
#   '미녀',
#   '왜냐면',
#   '마주치다',
#   'sleep',
#   '뭐라다',
#   '하든',
#   '위너',
#   '근데',
#   'YELLIN',
#   '알다',
#   'Team',
#   '인생',
#   '천만',
#   '관람',
#   '무비',
#   '그냥',
#   '유튜브',
#   '있다',
#   '클립',
#   '역시',
#   'ball',
#   'baby',
#   '그래서',
#   '자다',
#   '보다',
#   'ballin',
#   '같다',
#   'callin',
#   'me',
#   'ha',
#   '받다',
#   '졸림',
#   'No',
#   'kizzy',
#   'no',
#   'kidding',
#   '나르다',
#   '앞서다',
#   'sliding',
#   'Fleeky',
#   'Bang',
#   '빠지다',
#   'party',
#   '소리치다',
#   'Gang',
#   'gang',
#   'gang',
#   'Aye',
#   'hop',
#   'out',
#   '축구',
#   '아니다',
#   'ball',
#   '가방',
#   '귀신',
#   '같이',
#   '갑자기',
#   '튀어나오다',
#   'yeah',
#   'pop',
#   'out',
#   '걔네',
#   '거짓말',
#   '치다',
#   '니까',
#   '전부',
#   '들리다',
#   '사탄',
#   '넘다',
#   '맵다',
#   '불닭',
#   'taste',
#   'sweet',
#   'like',
#   '사탕',
#   '올라가다',
#   '매일',
#   '오다',
#   '꼭대기',
#   'My',
#   'mama',
#   'told',
#   'me',
#   'can',
#   'be',
#   'something',
#   'big',
#   'We',
#   'on',
#   'fire',
#   '이건',
#   '우릴',
#   '올라가다',
#   '매일',
#   '오다',
#   '꼭대기',
#   'My',
#   'mama',
#   'told',
#   'me',
#   'can',
#   'be',
#   'something',
#   'big',
#   'We',
#   'on',
#   'fire',
#   '이건',
#   '우릴'],
#  ['에도', '듣다', '사람'],
#  ['호미', '개미', '치다', '진짜', 'ㅋㅋㅋ'],
#  ['새해'],
#  ['Blase', 'Blas'],
#  ['윤석열', '인정', '최고'],
#  ['이륙',
#   '테잌',
#   '오프',
#   '기세',
#   '마치',
#   '폭포',
#   '실패',
#   '몰다',
#   '빅토리',
#   '오다',
#   '관중',
#   '반짝',
#   '메이데이',
#   '쉬다',
#   '토스',
#   '작년',
#   '쓰다',
#   '아웃',
#   '에서부터',
#   '차리다',
#   '식사',
#   '허다',
#   '성급하다',
#   '성공',
#   '쇄도',
#   '공간',
#   '스루',
#   '패스',
#   '아이',
#   '케이',
#   '악센트',
#   '케이',
#   '시작',
#   '골방',
#   '이다',
#   '이제',
#   '우린',
#   '월드',
#   '와이드',
#   '포쇼',
#   '절대',
#   '덤벙',
#   '과거',
#   '컴컴하다',
#   '미랜',
#   '번쩍',
#   '딱딱하다',
#   '가지',
#   '빡빡',
#   '머리',
#   '벌써',
#   '나인',
#   '베이비',
#   '워리',
#   '이제',
#   '전성기',
#   '나이',
#   '나잇',
#   '쉬다',
#   '올라타다',
#   '아이',
#   '저스트',
#   '손흥민',
#   '처럼',
#   '아이',
#   '보이',
#   '함성',
#   '소리',
#   '덮다',
#   '치다',
#   '기회',
#   '오다',
#   '아이',
#   '배럴',
#   '기회',
#   '오다',
#   '터치',
#   '스카이',
#   '그렇다',
#   '닿다',
#   '대기권',
#   '바닥',
#   '떨어지다',
#   '없다',
#   '마이',
#   '프로파일',
#   '말고는',
#   '재미없다',
#   '패배',
#   '있다',
#   '더욱더',
#   '단단하다',
#   '배우다',
#   '거지',
#   '다른',
#   '지금',
#   '이기다',
#   '에만',
#   '쏟다',
#   '그릴',
#   '각자',
#   '자리',
#   '윤하',
#   '에브리',
#   '웨얼',
#   '여기저기',
#   '있다',
#   '계속',
#   '네버',
#   '스탑',
#   '괴롭다',
#   '라잌',
#   '박스',
#   '박스',
#   '넘버',
#   '에잇',
#   '트랩',
#   '배다',
#   '드릴',
#   '상관없다',
#   '뱉다',
#   '크다',
#   '엠씨',
#   '진짜',
#   '래퍼',
#   '유행',
#   '같다',
#   '타지',
#   '않다',
#   '여름',
#   '가을',
#   '겨울',
#   '제철',
#   '에이',
#   '브라',
#   '올라가다',
#   '너무',
#   '높다',
#   '어떡하다',
#   '우린',
#   '떨어지다',
#   '절대',
#   '돼다',
#   '겁쟁이',
#   '언제나',
#   '멋대로',
#   '멀다',
#   '눈앞',
#   '저스트',
#   '잇다',
#   '마이',
#   '브라더',
#   '이루다',
#   '위해',
#   '목표',
#   '생각',
#   '일단',
#   '펼치다',
#   '치다',
#   '번만',
#   '보다',
#   '에는',
#   '나오다',
#   '이번',
#   '기회',
#   '플라이',
#   '올라가다',
#   '매일',
#   '오다',
#   '꼭대기',
#   '마이',
#   '마마',
#   '밉다',
#   '섬띵',
#   '파이어',
#   '이건',
#   '우릴',
#   '올라가다',
#   '매일',
#   '오다',
#   '꼭대기',
#   '마이',
#   '마마',
#   '밉다',
#   '섬띵',
#   '파이어',
#   '이건',
#   '우릴',
#   '실패',
#   '절대',
#   '두렵다',
#   '않다',
#   '넘어지다',
#   '포기',
#   '따윈',
#   '알다',
#   '막다',
#   '장애물',
#   '있다',
#   '멈칫',
#   '않다',
#   '깊다',
#   '들이마시다',
#   '이륙',
#   '준비',
#   '날다',
#   '결국',
#   '트로피',
#   '거머쥐',
#   '나서다',
#   '기회',
#   '바로',
#   '잡다',
#   '꿈꾸다',
#   '오다',
#   '감다',
#   '들리다',
#   '함성',
#   '소리',
#   '누가',
#   '뭐라다',
#   '오직',
#   '목표',
#   '하나',
#   '황소',
#   '고집',
#   '플리',
#   '키뱅',
#   '호미',
#   '윤하',
#   '블라세',
#   '키츠',
#   '요지',
#   '우리',
#   '국가대표',
#   '귀엽다',
#   '마치',
#   '슛돌이',
#   '몸싸움',
#   '내버리다',
#   '멀리',
#   '만약',
#   '들다',
#   '벤치',
#   '클리어',
#   '귓가',
#   '이명',
#   '대신',
#   '울리다',
#   '승리',
#   '나팔',
#   '소리',
#   'La',
#   'lala',
#   'lalala',
#   '넘기다',
#   '바입스',
#   '다섯',
#   '훈련',
#   '마이',
#   '타임',
#   '이스',
#   '티킹',
#   '구르다',
#   '매일',
#   '박아',
#   '테이',
#   '리스',
#   '어차피',
#   '아니다',
#   '있다',
#   '고생',
#   '다음',
#   '에는',
#   '최고',
#   '아니다',
#   '자신감',
#   '앞뒤',
#   '가리다',
#   '비릿',
#   '라이프',
#   '패스',
#   '스코어',
#   '롸잇',
#   '잇프',
#   '타임',
#   '디스',
#   '얘기',
#   '워스',
#   '잇다',
#   '포기',
#   '오다',
#   '여기',
#   '다시',
#   '부어',
#   '전부',
#   '마이',
#   '라이프',
#   '마이',
#   '개스',
#   '오르다',
#   '마잌',
#   '주다',
#   '패스',
#   '아웃',
#   '오다',
#   '스털디',
#   '스털디',
#   '나티',
#   '나티',
#   '보이다',
#   '드디어',
#   '성공',
#   '돈트',
#   '워리',
#   '워리',
#   '스컬',
#   '스컬',
#   '라이프',
#   '있다',
#   '여기저기',
#   '트로피',
#   '없다',
#   '잇츠',
#   '타임',
#   '디스',
#   '멀다',
#   '멀다',
#   '올라가다',
#   '매일',
#   '오다',
#   '꼭대기',
#   '마이',
#   '마마',
#   '밉다',
#   '섬띵',
#   '파이어',
#   '이건',
#   '우릴',
#   '올라가다',
#   '매일',
#   '오다',
#   '꼭대기',
#   '마이',
#   '마마',
#   '밉다',
#   '섬띵',
#   '파이어',
#   '이건',
#   '우릴',
#   '멈추다',
#   '있다',
#   '스톱',
#   '사인',
#   'SCH',
#   'YEL',
#   '스핀',
#   '한국',
#   '남자',
#   '래퍼',
#   '미녀',
#   '왜냐면',
#   '마주치다',
#   '슬립',
#   '뭐라다',
#   '하든',
#   '위너',
#   '근데',
#   '옐린',
#   '알다',
#   '에이',
#   '인생',
#   '천만',
#   '관람',
#   '무비',
#   '그냥',
#   '유튜브',
#   '있다',
#   '클립',
#   '역시',
#   '베이비',
#   '그래서',
#   '자다',
#   '보다',
#   '발린',
#   '같다',
#   '컬린',
#   '밉다',
#   '받다',
#   '졸림',
#   '키딩',
#   '나르다',
#   '앞서다',
#   '슬라이딩',
#   '플리',
#   '빠지다',
#   '파티',
#   '소리치다',
#   '에이',
#   '아웃',
#   '축구',
#   '아니다',
#   '가방',
#   '귀신',
#   '같이',
#   '갑자기',
#   '튀어나오다',
#   '아웃',
#   '걔네',
#   '거짓말',
#   '치다',
#   '니까',
#   '전부',
#   '들리다',
#   '사탄',
#   '넘다',
#   '맵다',
#   '불닭',
#   '이스트',
#   '스윗',
#   '라잌',
#   '사탕',
#   '올라가다',
#   '매일',
#   '오다',
#   '꼭대기',
#   '마이',
#   '마마',
#   '밉다',
#   '섬띵',
#   '파이어',
#   '이건',
#   '우릴',
#   '올라가다',
#   '매일',
#   '오다',
#   '꼭대기',
#   '마이',
#   '마마',
#   '밉다',
#   '섬띵',
#   '파이어',
#   '이건',
#   '우릴'],
#  ['매일', '오다', '꼭대기', '네이마르', '추껍', '대기', '들리다'],
#  ['피파', '추억', '생각나다', 'ㅠㅠ'],
#  ['작년', '피파', '유저', '라면', '모르다', '없다', '노래'],
#  ['오다', '이윤'],
#  ['피파', '그때', '시절', '노래'],
#  ['피파', '노래'],
#  ['님들', '무슨', '노래', '인지', '모르다', '알다', '대충', '이렇다', '제발', '찾다', 'ㅜㅜ'],
#  ['좋다'],
#  ['플리', '키뱅', '파트', '린다', 'ㅎㄷㄷ'],
#  ['이노', '추억', '돼다'],
#  ['올라가다',
#   '매일',
#   '바라다',
#   '오다',
#   '꼭대기',
#   'My',
#   'nama',
#   'told',
#   'me',
#   'can',
#   'be',
#   'something',
#   'big',
#   'We',
#   'on',
#   'fire',
#   '이건',
#   '우릴',
#   '올라가다',
#   '매일',
#   '오다',
#   '꼭대기',
#   'My',
#   'nama',
#   'told',
#   'me',
#   'can',
#   'be',
#   'something',
#   'big',
#   'We',
#   'on',
#   'fire',
#   '이건',
#   '우릴',
#   '현실',
#   '올라가다',
#   '매일',
#   '오다',
#   '꼭대기',
#   'My',
#   'big',
#   'We',
#   'on',
#   'fire',
#   '이건',
#   '우릴'],
#  ['쉬다', '토스'],
#  ['에도', '듣다', '사람', '기모'],
#  ['𝐏𝐥𝐚𝐲𝐥𝐢𝐬𝐭',
#   '𝐓𝐢𝐦𝐞𝐥𝐢𝐧𝐞',
#   '가다',
#   '표기',
#   '되어다',
#   '주인',
#   '추천',
#   'PICK',
#   '스포티파이',
#   '𝐒𝐩𝐨𝐭𝐢𝐟𝐲',
#   '에서',
#   '듣기',
#   'Austin',
#   'White',
#   'Tre',
#   'Gadd',
#   'Step',
#   'Inside',
#   'Vic',
#   'Sage',
#   'DISGUSTING',
#   'FREESTYLE',
#   'Armani',
#   'White',
#   'Ludacris',
#   'BILLIE',
#   'EILISH',
#   'LEGENDS',
#   'MIX',
#   'Hudi',
#   'Holy',
#   'Smokes',
#   'Kanye',
#   'West',
#   'JAY',
#   'Big',
#   'Sean',
#   'Clique',
#   'ZAAC',
#   'Tyga',
#   'Anitta',
#   'PA',
#   'PA',
#   'PA',
#   'Sugs',
#   'Archive',
#   'Sugs',
#   'TAHIT',
#   'II',
#   'Vic',
#   'Sage',
#   'Chuuwee',
#   'TAX',
#   'Ice',
#   'Spice',
#   'Nicki',
#   'Minaj',
#   'Princess',
#   'Diana',
#   'Matt',
#   'Corman',
#   'IN',
#   'MY',
#   'HANDS',
#   'Kendrick',
#   'Lamar',
#   'Not',
#   'Like',
#   'Us',
#   'Chainz',
#   'Dugg',
#   'Million',
#   'Dollars',
#   'Worth',
#   'of',
#   'Game',
#   'Nic',
#   'Connor',
#   'Price',
#   'Still',
#   'Hot',
#   'Matt',
#   'Corman',
#   'HOW',
#   'IT',
#   'GOES',
#   'Abhi',
#   'The',
#   'Nomad',
#   'JZAC',
#   'Kato',
#   'On',
#   'The',
#   'Track',
#   'KD',
#   'Money',
#   'Eazy',
#   'AP',
#   'Rocky',
#   'Cardi',
#   'No',
#   'Limit',
#   'Armani',
#   'White',
#   'DIAMOND',
#   'DALLS',
#   'Woah',
#   'Saweetie',
#   'Doja',
#   'CAt',
#   'Best',
#   'Friend',
#   'Eldritch',
#   'CAIRO',
#   'INSOMNIAC',
#   'Connor',
#   'Price',
#   'Haviah',
#   'Mighty',
#   'Trendsetter',
#   'Hudi',
#   'Rain',
#   'Tyga',
#   'It',
#   'Ain',
#   'Safe',
#   'Austin',
#   'White',
#   'Big',
#   'Faith',
#   'Foolin',
#   'Matt',
#   'Corman',
#   'CASH',
#   'NAP',
#   'Pertinence',
#   'UPS',
#   'DOWNS',
#   'Armani',
#   'White',
#   'Denzel',
#   'Curry',
#   'GOATED',
#   'bbno',
#   'Ientra',
#   'big',
#   'boss',
#   'baby',
#   'Adam',
#   'Oh',
#   'GO',
#   'STUPID',
#   'GO',
#   'CRAZY',
#   'Jidenna',
#   'GoldLink',
#   'Babouche',
#   'Ollie',
#   'JHoseph',
#   'HUSH',
#   'Eliantte',
#   'Tyga',
#   'My',
#   'Thrn',
#   'Bugus',
#   'Just',
#   'Know',
#   'Vic',
#   'Sage',
#   'Ollie',
#   'Joseph',
#   'Jealous',
#   'Andy',
#   'Mineo',
#   'Lecrae',
#   'Coming',
#   'In',
#   'Hot',
#   'Kharii',
#   'Venti',
#   'Bugus',
#   'Gotta',
#   'Get',
#   'It',
#   'Bugus',
#   'Im',
#   'the',
#   'One',
#   'Lil',
#   'Nas',
#   'Jack',
#   'Harlow',
#   'INDUSTRY',
#   'BABY',
#   'Connor',
#   'Price',
#   'Ktlyn',
#   'NEW',
#   'PHONE',
#   'Ollie',
#   'Joseph',
#   'Letterman',
#   'Jocks',
#   'Nate',
#   'Rose',
#   'Truent',
#   'Badminton',
#   'Freestyle',
#   'Scepaz',
#   'NJE',
#   'Big',
#   'Spender',
#   'ix',
#   'ine',
#   'Yaillin',
#   'Ia',
#   'Mas',
#   'Viral',
#   'Shaka',
#   'Laka',
#   'Lilo',
#   'Key',
#   'Keep',
#   'Dreaming',
#   'Daven',
#   'Wilson',
#   'BIG',
#   'LEO',
#   'ENERGY'],
#  ['얼마나', '바쁘다', '계속', '바쁘다', '그렇다'],
#  ['오다', '지기'],
#  ['fucking', 'good', 'bro'],
#  ['노래', '진짜', '좋다', '출퇴근', '듣다'],
#  ['님들', '이우', '이우', '시작', '외국', '힙합', '노래', '제목', '아시'],
#  ['진짜', '지리'],
#  ['자다', '말다', '보통', '듣다', '사람', '가다', '흉내', '내다'],
#  ['오다', '디깅', '직업', '이신가', '하루', '종일', '디깅', '가요', '어케', '찾다', '이렇다', '노래'],
#  ['노래', '개쩌'],
#  ['밉다', '간과', '지린다', '모양', '검증'],
#  ['찢기다'],
#  ['사골', '돌리다', '먹기'],
#  ['쩔다'],
#  ['진짜', '클럽', '하나', '차리다', '매일', '갈다', 'ㅠㅠㅠㅠ', '미치다'],
#  ['진짜', '듣다', '좋다', '누르다'],
#  ['돌다', '버리다'],
#  ['이거지'],
#  ['두번째', '기다', '이랑', '목소리', '너무', '똑같다', 'ㄷㄷ'],
#  ['이번', '미치다'],
#  ['운전', '들다', '되다'],
#  ['여기', '노래', '스포티파이', '많다', '유튜브', '뮤직', '많다'],
#  ['need', 'more', 'of', 'this', 'playlist', 'ty'],
#  ['대체', '이렇다', '미치다', '띵곡', '어디서', '찾다', '니까', '항상', '믿다', '들다'],
#  ['도입', '찢다', '버리다'],
#  ['개추'],
#  ['언제', '올리다', '웹툰', '보다', '들다'],
#  ['썸넬', '부터', '합격'],
#  ['쓰다'],
#  ['형님', 'DopE', '감사하다'],
#  ['쌈뽕'],
#  ['오우', '취저', '인데', 'yo'],
#  ['떳다', '야스'],
#  ['서다', '기분', '구리다', '넘다', '좋슴돠'],
#  ['읽다', '분들', '모든', '일이', '자다', '되다', '겁니다', '모두', '행복하다'],
#  ['진짜', '좋다'],
#  ['진짜', '안에', '찢다', '버리다'],
#  ['덕분', '오늘', '시원하다', '지리', '가다'],
#  ...]

# %%
# from gensim.models import Word2Vec

# model = Word2Vec(sentences = tokenized_data, vector_size = 100, window = 5, min_count = 5, workers = 4, sg = 0)

# %%
# model.wv.vectors.shape
# Out:
# (5386, 100)

# %%
# print(model.wv.most_similar("감성"))
# Out:
# [('이노', 0.9982504844665527), ('ㅎㅎ', 0.996608555316925), ('중독', 0.996231198310852), ('충격', 0.9956544637680054), ('생각나다', 0.9955595135688782), ('음원', 0.9952946901321411), ('모으다', 0.9952518343925476), ('ㅜㅜ', 0.9948887825012207), ('스타일', 0.9947054982185364), ('연말', 0.9946438074111938)]

# %%
# Word2Vec 모델을 .bin 형태가 아니라 텍스트 포맷으로 저장

# model.wv.save_word2vec_format("data-files/ko_w2v")

# %%
# Gensim에서 제공하는 스크립트로, Word2Vec 데이터를 TensorBoard에서 Embedding Projector로 볼 수 있도록 .tsv 파일 2개로 변환

# ko_w2v_tensor.tsv (vectors)
# ko_w2v_metadata.tsv (단어 목록)

# !python -m gensim.scripts.word2vec2tensor --input outputs/word2vec/ko_w2v --output outputs/word2vec/ko_w2v
# !python -m gensim.scripts.word2vec2tensor --input ko_w2v --output ko_w2v

# 경로에 맞게 실행문장
# !python -m gensim.scripts.word2vec2tensor --input data-files/ko_w2v --output data-files/ko_w2v
# Out:
# 2025-05-05 11:24:48,018 - word2vec2tensor - INFO - running C:\Users\tq100\AppData\Roaming\Python\Python311\site-packages\gensim\scripts\word2vec2tensor.py --input data-files/ko_w2v --output data-files/ko_w2v
# 2025-05-05 11:24:48,018 - keyedvectors - INFO - loading projection weights from data-files/ko_w2v
# 2025-05-05 11:24:48,894 - utils - INFO - KeyedVectors lifecycle event {'msg': 'loaded (5386, 100) matrix of type float32 from data-files/ko_w2v', 'binary': False, 'encoding': 'utf8', 'datetime': '2025-05-05T11:24:48.783354', 'gensim': '4.3.3', 'python': '3.11.11 | packaged by Anaconda, Inc. | (main, Dec 11 2024, 16:34:19) [MSC v.1929 64 bit (AMD64)]', 'platform': 'Windows-10-10.0.26100-SP0', 'event': 'load_word2vec_format'}
# 2025-05-05 11:24:49,481 - word2vec2tensor - INFO - 2D tensor file saved to data-files/ko_w2v_tensor.tsv
# 2025-05-05 11:24:49,482 - word2vec2tensor - INFO - Tensor metadata file saved to data-files/ko_w2v_metadata.tsv
# 2025-05-05 11:24:49,482 - word2vec2tensor - INFO - finished running word2vec2tensor.py
